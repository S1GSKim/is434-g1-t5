# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# users = ['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph'])
import re
from newspaper import Article
users = ['BuzzFeed']
filters = ['Covid-19 since:2020-12-01', 'until:2021-02-28']
from_filters = []
for user in users:
    from_filters.append(f'from:{user}')
filters.append(' OR '.join(from_filters))
tweets = list(sntwitter.TwitterSearchScraper(' '.join(filters)).get_items())
print(len(tweets))
tweet_list=[]
count=1
for tweet in tweets:
    tweetContent=tweet.rawContent
    try:
        url = re.search("(?P<url>https?://[^\s]+)", tweetContent).group("url")
        print(url)
        count+=1
        try:
            toi_article = Article(url, language="en") # en for English

            #To download the article
            toi_article.download()

            #To parse the article
            toi_article.parse()

            #To perform natural language processing ie..nlp
            toi_article.nlp()

            tweet_list.append([tweet.date, tweet.retweetCount, toi_article.text, tweet.user.username, toi_article.keywords])
            print("Able to Scrape article"+str(count))
        except:
            tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
            print("Unable to Scrape article"+str(count))
    except:
        tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
        print("Unable to Scrape article"+str(count))
df_first = pd.DataFrame(tweet_list, columns=['Datetime','retweetCount','Text', 'Username','Keywords'])
df_first.drop_duplicates(subset='Text', keep="last")
df_first.head(30)
# Out:
# 37
# https://t.co/1wQ0x6YIMJ
# Unable to Scrape article2
# https://t.co/wUwzt6N57x
# Unable to Scrape article3
# https://t.co/26PmPKp0mt
# Able to Scrape article4
# https://t.co/y7B9TfWzlB
# Able to Scrape article5
# https://t.co/wnwEmQNOSj
# Able to Scrape article6
# https://t.co/I8WiXN07s2
# Able to Scrape article7
# https://t.co/w9HJ7kXijQ
# Unable to Scrape article8
# https://t.co/shbTBSedrv
# Able to Scrape article9
# https://t.co/WcsfFwOamA
# Able to Scrape article10
# https://t.co/Mfqi2XNHcj
# Unable to Scrape article11
# https://t.co/AE3VMBUBa6
# Able to Scrape article12
# https://t.co/rq6vPMhT9b
# Unable to Scrape article13
# https://t.co/a2vFUiUDgX
# Able to Scrape article14
# https://t.co/VXmlR1tjAx
# Able to Scrape article15
# https://t.co/NGlftOgCSN
# Able to Scrape article16
# https://t.co/zb2mwYIWcM
# Unable to Scrape article17
# https://t.co/z5fuuO9Y6i
# Unable to Scrape article18
# https://t.co/1VAxMdA5qH
# Able to Scrape article19
# https://t.co/7C9znQTOgN
# Unable to Scrape article20
# https://t.co/YVMEDYoANI
# Unable to Scrape article21
# https://t.co/lhoLhChBkF
# Able to Scrape article22
# https://t.co/PnRIsiFAD5
# Able to Scrape article23
# https://t.co/zb8pI4Z3RY
# Able to Scrape article24
# https://t.co/MiAaIdrLwL
# Able to Scrape article25
# https://t.co/oTju21iu5Z
# Able to Scrape article26
# https://t.co/FK4DGB9zQi
# Able to Scrape article27
# https://t.co/76D4jdC7iO
# Unable to Scrape article28
# https://t.co/scy75AW2Jm
# Able to Scrape article29
# https://t.co/HUNQ2KJ7ez
# Able to Scrape article30
# https://t.co/HZJaE66omM
# Unable to Scrape article31
# https://t.co/eSt1epgYvZ
# Able to Scrape article32
# https://t.co/3xMbg53QeE
# Able to Scrape article33
# https://t.co/j1NZRgexh8
# Unable to Scrape article34
# https://t.co/NmslewvGBi
# Able to Scrape article35
# https://t.co/NJh3C7xJCt
# Able to Scrape article36
# https://t.co/waGjJCqDLa
# Able to Scrape article37
# https://t.co/szV5c6mwRQ
# Able to Scrape article38
#                     Datetime  retweetCount  \
# 0  2021-02-26 22:07:53+00:00             8
# 1  2021-02-08 17:00:12+00:00             9
# 2  2021-02-05 14:12:34+00:00             6
# 3  2021-02-02 23:30:34+00:00            37
# 4  2021-02-02 17:00:17+00:00            18
# 5  2021-01-28 16:44:08+00:00             1
# 6  2021-01-26 21:21:37+00:00             5
# 7  2021-01-22 16:53:03+00:00            12
# 8  2021-01-20 10:00:47+00:00            25
# 9  2021-01-17 15:00:39+00:00            12
# 10 2021-01-14 22:05:03+00:00            17
# 11 2021-01-12 21:31:13+00:00            13
# 12 2021-01-12 18:27:25+00:00             5
# 13 2021-01-05 17:52:05+00:00            15
# 14 2020-12-23 22:12:50+00:00            12
# 15 2020-12-22 19:35:03+00:00             6
# 16 2020-12-22 18:23:27+00:00             8
# 17 2020-12-20 14:46:28+00:00            16
# 18 2020-12-19 21:20:41+00:00            34
# 19 2020-12-19 01:10:11+00:00            38
# 20 2020-12-19 00:36:20+00:00            24
# 21 2020-12-16 17:04:43+00:00             8
# 22 2020-12-15 21:43:00+00:00             6
# 23 2020-12-14 21:03:11+00:00            23
# 24 2020-12-13 19:17:23+00:00            22
# 25 2020-12-10 20:30:19+00:00             6
# 26 2020-12-10 17:35:08+00:00            13
# 27 2020-12-08 22:48:59+00:00            14
# 28 2020-12-08 21:59:00+00:00           142
# 29 2020-12-08 21:25:28+00:00             6
#
#                                                  Text  Username  \
# 0   Johnson &amp;amp; Johnson's vaccine has been s...  BuzzFeed
# 1   The Republican lawmaker is the first sitting m...  BuzzFeed
# 2   As a public defender, my job is to represent p...  BuzzFeed
# 3   "Your olfactory nerve, the nerve involved in y...  BuzzFeed
# 4   Capt. Tom Moore, the 100-year-old British vete...  BuzzFeed
# 5   JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 6   Biden extended COVID-19 travel restrictions fo...  BuzzFeed
# 7   JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 8   In the first hours of his presidency, Joe Bide...  BuzzFeed
# 9   Complications of COVID-19 have caused many peo...  BuzzFeed
# 10  In the wake of last week’s attack on the Capit...  BuzzFeed
# 11  While the store has backtracked, there's still...  BuzzFeed
# 12  Operation Warp Speed officials changed course ...  BuzzFeed
# 13  Malvina Shabes, known as “Visia” to friends, w...  BuzzFeed
# 14  An 82-year-old COVID-19 patient was beaten to ...  BuzzFeed
# 15  A court reduced Sklyar Mack's prison sentence ...  BuzzFeed
# 16  It is impossible to make sense of the more tha...  BuzzFeed
# 17  But have you ever thought about how, say, Lesl...  BuzzFeed
# 18  The man filled out a pre-flight checklist stat...  BuzzFeed
# 19  Of the more than 1,300 residents at Stanford M...  BuzzFeed
# 20  The journalists at BuzzFeed News are proud to ...  BuzzFeed
# 21  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 22  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 23  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 24  The first shipments of the COVID-19 vaccine se...  BuzzFeed
# 25  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 26  Ellen DeGeneres Announced She Tested Positive ...  BuzzFeed
# 27  Erica Becerra had recently moved to Detroit fr...  BuzzFeed
# 28  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 29  Biden Plans To Give 50 Million Americans COVID...  BuzzFeed
#
#                                              Keywords
# 0                                                  []
# 1                                                  []
# 2   [im, covid, clients, defender, prison, jail, f...
# 3   [palmer, loss, tiktok, recipe, moms, orange, s...
# 4   [capt, raised, hannah, healthcare, ward, milli...
# 5   [javascript, list, help, supported, disabled, ...
# 6                                                  []
# 7   [javascript, list, help, supported, disabled, ...
# 8   [trumps, orders, joe, immigrants, executive, s...
# 9                                                  []
# 10  [days, work, week, congress, virus, cases, wea...
# 11                                                 []
# 12  [vaccine, doses, nationwide, million, trump, a...
# 13  [escaped, son, told, kind, holocaust, malvina,...
# 14  [lancaster, hospital, beaten, patient, prayed,...
# 15                                                 []
# 16                                                 []
# 17  [weve, leslie, threats, schmidt, knope, tv, ch...
# 18                                                 []
# 19                                                 []
# 20  [vaccine, doses, americans, fda, million, auth...
# 21  [javascript, list, help, supported, disabled, ...
# 22  [javascript, list, help, supported, disabled, ...
# 23  [javascript, list, help, supported, disabled, ...
# 24  [vaccine, trucks, workers, pfizers, carrying, ...
# 25  [javascript, list, help, supported, disabled, ...
# 26                                                 []
# 27  [son, youve, gave, began, died, wrote, family,...
# 28  [javascript, list, help, supported, disabled, ...
# 29                                                 []

# %%
# users = ['ABC','CBSNews','CNN','nytimes','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost','politico','CNET']
import re
from newspaper import Article
users = ['BuzzFeed']
filters = ['Covid-19 since:2022-01-01', 'until:2022-03-31']
from_filters = []
for user in users:
    from_filters.append(f'from:{user}')
filters.append(' OR '.join(from_filters))
tweets = list(sntwitter.TwitterSearchScraper(' '.join(filters)).get_items())
print(len(tweets))
tweet_list=[]
count=1
for tweet in tweets:
    tweetContent=tweet.rawContent
    try:
        url = re.search("(?P<url>https?://[^\s]+)", tweetContent).group("url")
        print(url)
        count+=1
        try:
            toi_article = Article(url, language="en") # en for English

            #To download the article
            toi_article.download()

            #To parse the article
            toi_article.parse()

            #To perform natural language processing ie..nlp
            toi_article.nlp()

            tweet_list.append([tweet.date, tweet.retweetCount, toi_article.text, tweet.user.username, toi_article.keywords])
            print("Able to Scrape article"+str(count))
        except:
            tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
            print("Unable to Scrape article"+str(count))
    except:
        tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
        print("Unable to Scrape article"+str(count))
df_second = pd.DataFrame(tweet_list, columns=['Datetime','retweetCount','Text', 'Username','Keywords'])
df_second.drop_duplicates(subset='Text', keep="last")
df_second.head()
# Out:
# 10
# https://t.co/a8TdINS23j
# Able to Scrape article2
# Unable to Scrape article2
# https://t.co/fL6AdDT8Zv
# Unable to Scrape article3
# https://t.co/GesFl0egIJ
# Able to Scrape article4
# https://t.co/xcOe4mJdqk
# Able to Scrape article5
# https://t.co/SFHNpkAbGd
# Able to Scrape article6
# https://t.co/POXeyhBcUm
# Able to Scrape article7
# https://t.co/PHsHqFkTyS
# Able to Scrape article8
# https://t.co/XQNWrTVzxt
# Able to Scrape article9
# https://t.co/esQ5Kd28o4
# Able to Scrape article10
#                    Datetime  retweetCount  \
# 0 2022-02-27 23:31:49+00:00             0
# 1 2022-02-16 00:10:59+00:00             1
# 2 2022-02-05 00:20:11+00:00             0
# 3 2022-02-04 17:25:11+00:00             0
# 4 2022-01-31 01:45:05+00:00             7
#
#                                                 Text  Username  \
# 0  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 1  "By entering the festival, attendees voluntari...  BuzzFeed
# 2  As the Olympic Games start, cyberattacks and C...  BuzzFeed
# 3  Others have encouraged celebrities to keep usi...  BuzzFeed
# 4  "This is not the way. This is not safe. This i...  BuzzFeed
#
#                                             Keywords
# 0  [javascript, list, help, supported, disabled, ...
# 1                                                 []
# 2                                                 []
# 3  [stay, platforms, celebrities, lebron, politic...
# 4  [evangeline, fear, world, antivax, understand,...

# %%
df_final=pd.concat([df_first, df_second], ignore_index=True)
df_final.head(30)
# Out:
#                     Datetime  retweetCount  \
# 0  2021-02-26 22:07:53+00:00             8
# 1  2021-02-08 17:00:12+00:00             9
# 2  2021-02-05 14:12:34+00:00             6
# 3  2021-02-02 23:30:34+00:00            37
# 4  2021-02-02 17:00:17+00:00            18
# 5  2021-01-28 16:44:08+00:00             1
# 6  2021-01-26 21:21:37+00:00             5
# 7  2021-01-22 16:53:03+00:00            12
# 8  2021-01-20 10:00:47+00:00            25
# 9  2021-01-17 15:00:39+00:00            12
# 10 2021-01-14 22:05:03+00:00            17
# 11 2021-01-12 21:31:13+00:00            13
# 12 2021-01-12 18:27:25+00:00             5
# 13 2021-01-05 17:52:05+00:00            15
# 14 2020-12-23 22:12:50+00:00            12
# 15 2020-12-22 19:35:03+00:00             6
# 16 2020-12-22 18:23:27+00:00             8
# 17 2020-12-20 14:46:28+00:00            16
# 18 2020-12-19 21:20:41+00:00            34
# 19 2020-12-19 01:10:11+00:00            38
# 20 2020-12-19 00:36:20+00:00            24
# 21 2020-12-16 17:04:43+00:00             8
# 22 2020-12-15 21:43:00+00:00             6
# 23 2020-12-14 21:03:11+00:00            23
# 24 2020-12-13 19:17:23+00:00            22
# 25 2020-12-10 20:30:19+00:00             6
# 26 2020-12-10 17:35:08+00:00            13
# 27 2020-12-08 22:48:59+00:00            14
# 28 2020-12-08 21:59:00+00:00           142
# 29 2020-12-08 21:25:28+00:00             6
#
#                                                  Text  Username  \
# 0   Johnson &amp;amp; Johnson's vaccine has been s...  BuzzFeed
# 1   The Republican lawmaker is the first sitting m...  BuzzFeed
# 2   As a public defender, my job is to represent p...  BuzzFeed
# 3   "Your olfactory nerve, the nerve involved in y...  BuzzFeed
# 4   Capt. Tom Moore, the 100-year-old British vete...  BuzzFeed
# 5   JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 6   Biden extended COVID-19 travel restrictions fo...  BuzzFeed
# 7   JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 8   In the first hours of his presidency, Joe Bide...  BuzzFeed
# 9   Complications of COVID-19 have caused many peo...  BuzzFeed
# 10  In the wake of last week’s attack on the Capit...  BuzzFeed
# 11  While the store has backtracked, there's still...  BuzzFeed
# 12  Operation Warp Speed officials changed course ...  BuzzFeed
# 13  Malvina Shabes, known as “Visia” to friends, w...  BuzzFeed
# 14  An 82-year-old COVID-19 patient was beaten to ...  BuzzFeed
# 15  A court reduced Sklyar Mack's prison sentence ...  BuzzFeed
# 16  It is impossible to make sense of the more tha...  BuzzFeed
# 17  But have you ever thought about how, say, Lesl...  BuzzFeed
# 18  The man filled out a pre-flight checklist stat...  BuzzFeed
# 19  Of the more than 1,300 residents at Stanford M...  BuzzFeed
# 20  The journalists at BuzzFeed News are proud to ...  BuzzFeed
# 21  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 22  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 23  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 24  The first shipments of the COVID-19 vaccine se...  BuzzFeed
# 25  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 26  Ellen DeGeneres Announced She Tested Positive ...  BuzzFeed
# 27  Erica Becerra had recently moved to Detroit fr...  BuzzFeed
# 28  JavaScript is not available.\n\nWe’ve detected...  BuzzFeed
# 29  Biden Plans To Give 50 Million Americans COVID...  BuzzFeed
#
#                                              Keywords
# 0                                                  []
# 1                                                  []
# 2   [im, covid, clients, defender, prison, jail, f...
# 3   [palmer, loss, tiktok, recipe, moms, orange, s...
# 4   [capt, raised, hannah, healthcare, ward, milli...
# 5   [javascript, list, help, supported, disabled, ...
# 6                                                  []
# 7   [javascript, list, help, supported, disabled, ...
# 8   [trumps, orders, joe, immigrants, executive, s...
# 9                                                  []
# 10  [days, work, week, congress, virus, cases, wea...
# 11                                                 []
# 12  [vaccine, doses, nationwide, million, trump, a...
# 13  [escaped, son, told, kind, holocaust, malvina,...
# 14  [lancaster, hospital, beaten, patient, prayed,...
# 15                                                 []
# 16                                                 []
# 17  [weve, leslie, threats, schmidt, knope, tv, ch...
# 18                                                 []
# 19                                                 []
# 20  [vaccine, doses, americans, fda, million, auth...
# 21  [javascript, list, help, supported, disabled, ...
# 22  [javascript, list, help, supported, disabled, ...
# 23  [javascript, list, help, supported, disabled, ...
# 24  [vaccine, trucks, workers, pfizers, carrying, ...
# 25  [javascript, list, help, supported, disabled, ...
# 26                                                 []
# 27  [son, youve, gave, began, died, wrote, family,...
# 28  [javascript, list, help, supported, disabled, ...
# 29                                                 []

# %%
df_final['truthfulness']='0'

# %%
df_final.to_csv('BuzzFeed.csv', encoding='utf-8', index=False)
