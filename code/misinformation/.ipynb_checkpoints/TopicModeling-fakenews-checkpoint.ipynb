# %%
import nltk

# nltk.download('stopwords')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# %%
# Gensim (Topic Modeling Pacakge)
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
# spacy for lemmatization
import spacy

from spacy_download import load_spacy

# %%
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
'''
We will be using the 20-Newsgroups dataset for this exercise.
This version of the dataset contains about 11k newsgroups posts from 
20 different topics. This is available as newsgroups.json.
'''
# Import Dataset
df = pd.read_csv('disinformation_2ndclean(sm).csv')
print(df.Title.unique())
df.head()
# Out:
# ['India Is In The Middle Of A Coronavirus YouTube Frenzy, And It’s Going To Get People Killed'
#  'Tweet: False reporting on "shooting down" people with the virus in China'
#  'Tweet: A woman eating a delicacy, attributing the virus to eating "bat soup"'
#  ...
#  'Fact Check: There Are Currently NO Vaccines Available For COVID-19 In the U.S.'
#  "Fact Check: COVID-19 Is NOT 'The Most Highly Survivable Virus'"
#  'Report as if Japanese scientist speaks about manufactured coronavirus is fake']
#                                          Reported_On Additional_Reporting  \
# 0  https://www.buzzfeednews.com/article/ryanhates...                  NaN
# 1  https://twitter.com/Rangoli_A/status/122779241...                  NaN
# 2  https://twitter.com/Woppa1Woppa/status/1220068...                  NaN
# 3  https://twitter.com/FreddiGoldstein/status/123...                  NaN
# 4  https://www.boomlive.in/health/hoax-alert-vira...                  NaN
#
#                                      Retrieve_from_1 Retrieve_from_2  \
# 0  https://www.buzzfeednews.com/article/ryanhates...             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4  https://www.boomlive.in/health/hoax-alert-vira...             NaN
#
#   Retrieve_from_3  Twitter_Reference  \
# 0             NaN              False
# 1             NaN               True
# 2             NaN               True
# 3             NaN               True
# 4             NaN              False
#
#                                        Direct_Post_1 Direct_Post_2  \
# 0                                                NaN           NaN
# 1  https://twitter.com/Rangoli_A/status/122779241...           NaN
# 2  https://twitter.com/Woppa1Woppa/status/1220068...           NaN
# 3  https://twitter.com/FreddiGoldstein/status/123...           NaN
# 4                                                NaN           NaN
#
#   Direct_Post_3 Direct_Post_4  ...  \
# 0           NaN           NaN  ...
# 1           NaN           NaN  ...
# 2           NaN           NaN  ...
# 3           NaN           NaN  ...
# 4           NaN           NaN  ...
#
#                                Narrative_Description ChainMsg_or_Email  \
# 0  Hindi language YouTube account saying COVID-19...             False
# 1  Twitter user posting a compilation video of pe...             False
# 2  Twitter user posting a video of a celebrity ea...             False
# 3       Chain message of NYPD containment responses.              True
# 4  Chain message of Indian Health Ministry respon...              True
#
#      Motive                                 Motive_Description  \
# 0  Politics  Efforts to spread false claims on the origins ...
# 1      Fear  Twitter user stoking fear among other users, s...
# 2  Politics  Twitter user discrediting Chinese-American pop...
# 3      Fear  Chain message spread to stoke fear among Ameri...
# 4      Fear  Chain message spread to stoke fear among India...
#
#              Source Source_Description Distrib_Channel     Misinfo_Type  \
# 0  Individual actor     General public         Youtube       Conspiracy
# 1  Individual actor     General public         Twitter  False reporting
# 2  Individual actor     General public         Twitter  False reporting
# 3  Individual actor     General public         Twitter  False reporting
# 4  Individual actor     General public        Facebook  False reporting
#
#                              Key_Words  \
# 0         Coronavirus, India, bat soup
# 1         Coronavirus, China, shooting
# 2  Coronavirus, Chinese food, bat soup
# 3  Coronavirus, NYPD, containment zone
# 4  Coronavirus, India, travel advisory
#
#                                              Summary
# 0  Hindi language Youtube account suggesting COVI...
# 1  Tweet with video showing "people getting shot ...
# 2  Video of an individual eating a delicacy, and ...
# 3  Tweet with a screenshot of chain message sugge...
# 4  WhatsApp chain message circulating among India...
#
# [5 rows x 27 columns]

# %%
df.Summary
# Out:
# 0       Hindi language Youtube account suggesting COVI...
# 1       Tweet with video showing "people getting shot ...
# 2       Video of an individual eating a delicacy, and ...
# 3       Tweet with a screenshot of chain message sugge...
# 4       WhatsApp chain message circulating among India...
#                               ...
# 1264    A meme on Facebook claims new data from CDC sh...
# 1265    A meme on Facebook claims South Carolina issue...
# 1266    A Facebook post claims a doctor told her there...
# 1267    A Facebook post claims COVID-19 is the most hi...
# 1268    Report claims that Japanese Professor Tasuku H...
# Name: Summary, Length: 1269, dtype: object

# %%
df.count()
# Out:
# Reported_On               1269
# Additional_Reporting        68
# Retrieve_from_1            529
# Retrieve_from_2            104
# Retrieve_from_3             37
# Twitter_Reference         1269
# Direct_Post_1              632
# Direct_Post_2              275
# Direct_Post_3              153
# Direct_Post_4              111
# Title                     1266
# Publication_Date          1269
# Primary_Country           1269
# Secondary_Country          105
# Primary_Language          1269
# Main_Narrative            1269
# Recoded_Main_Narrative     568
# Narrative_Description     1269
# ChainMsg_or_Email         1269
# Motive                    1269
# Motive_Description        1269
# Source                    1269
# Source_Description        1269
# Distrib_Channel           1269
# Misinfo_Type              1269
# Key_Words                 1269
# Summary                   1269
# dtype: int64

# %%
'''
As you can see there are many emails, newline and extra spaces that is quite distracting.
Let’s get rid of them using regular expressions.
'''
# Convert to list
data = df.Title.tolist()


pprint(data[:1])
# Out:
# ['India Is In The Middle Of A Coronavirus YouTube Frenzy, And It’s Going To '
#  'Get People Killed']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['india', 'is', 'in', 'the', 'middle', 'of', 'coronavirus', 'youtube', 'frenzy', 'and', 'it', 'going', 'to', 'get', 'people', 'killed']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['india', 'is', 'in', 'the', 'middle', 'of', 'coronavirus', 'youtube', 'frenzy', 'and', 'it', 'going', 'to', 'get', 'people', 'killed']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Will download the model if it isn't installed yet 
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])



print(data_lemmatized[:1])
# Out:
# [['youtube', 'frenzy', 'go', 'get', 'people', 'kill']]

# %%
import gensim.corpora as corpora

# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]]

# %%
vocab = len(id2word.token2id)

pd.Series([t for tokens in data_words_bigrams for t in tokens if "_" in t]).unique()
# Out:
# array(['fact_check', 'conspiracy_theory', 'bill_gates', 'social_media',
#        'south_africa', 'health_organization', 'face_masks',
#        'donald_trump', 'tested_positive', 'south_african', 'new_york',
#        'social_distancing', 'cek_fakta', 'clarifications_regarding',
#        'anthony_fauci', 'covid__'], dtype=object)

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.058*"pandemic" + 0.046*"cause" + 0.042*"cure" + 0.035*"home" + '
#   '0.024*"pay" + 0.021*"bill" + 0.020*"conspiracy" + 0.015*"test" + '
#   '0.013*"blue" + 0.013*"tested_positive"'),
#  (1,
#   '0.223*"covid" + 0.068*"false" + 0.049*"claim" + 0.039*"mask" + 0.037*"say" '
#   '+ 0.023*"post" + 0.014*"evidence" + 0.013*"new" + 0.013*"trump" + '
#   '0.012*"case"'),
#  (2,
#   '0.213*"vaccine" + 0.034*"government" + 0.020*"pfizer" + '
#   '0.019*"donald_trump" + 0.019*"state" + 0.016*"work" + 0.014*"coronaviru" + '
#   '0.013*"develop" + 0.010*"fraud" + 0.010*"turn"'),
#  (3,
#   '0.067*"coronavirus" + 0.039*"test" + 0.023*"make" + 0.023*"viral" + '
#   '0.021*"take" + 0.019*"get" + 0.018*"doctor" + 0.018*"facebook" + '
#   '0.016*"news" + 0.015*"stop"'),
#  (4,
#   '0.044*"photo" + 0.029*"old" + 0.028*"wrong" + 0.027*"flu" + '
#   '0.026*"lockdown" + 0.025*"rate" + 0.024*"image" + 0.020*"bill_gate" + '
#   '0.019*"video" + 0.018*"disease"'),
#  (5,
#   '0.102*"people" + 0.038*"share" + 0.036*"kill" + 0.035*"fact_check" + '
#   '0.028*"number" + 0.023*"give" + 0.022*"quarantine" + 0.016*"world" + '
#   '0.013*"issue" + 0.013*"inaccurate"'),
#  (6,
#   '0.046*"due" + 0.034*"fund" + 0.027*"food" + 0.019*"call" + 0.018*"gate" + '
#   '0.016*"arrest" + 0.014*"charge" + 0.013*"want" + 0.012*"leave" + '
#   '0.011*"huge"'),
#  (7,
#   '0.108*"death" + 0.085*"fake" + 0.050*"spread" + 0.020*"misinformation" + '
#   '0.019*"plan" + 0.018*"confirm" + 0.015*"message" + 0.013*"headline" + '
#   '0.013*"lead" + 0.012*"crisis"'),
#  (8,
#   '0.101*"die" + 0.028*"research" + 0.026*"offer" + 0.021*"infect" + '
#   '0.019*"free" + 0.017*"cancer" + 0.012*"hand" + 0.012*"election" + '
#   '0.011*"declare" + 0.011*"story"'),
#  (9,
#   '0.056*"video" + 0.046*"report" + 0.044*"show" + 0.043*"virus" + '
#   '0.022*"receive" + 0.022*"year" + 0.022*"circulate" + 0.019*"online" + '
#   '0.018*"medical" + 0.017*"outbreak"')]

# %%
'''
Model perplexity and topic coherence provide a convenient measure to judge 
how good a given topic model is. In my experience, topic coherence score, 
in particular, has been more helpful.
'''
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.5359243016393265
#
# Coherence Score:  0.5745818333199714

# %%
'''
Now that the LDA model is built, the next step is to examine the produced 
topics and the associated keywords. There is no better tool than pyLDAvis package’s 
interactive chart and is designed to work well with jupyter notebooks.
'''
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# C:\Users\hannah.kim\AppData\Roaming\Python\Python39\site-packages\pyLDAvis\_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.355468  0.153990       1        1  27.871359
# 3     -0.133368 -0.318117       2        1  18.789227
# 9      0.089325  0.043619       3        1   9.228582
# 4      0.089303  0.007957       4        1   8.949883
# 7      0.055171  0.012676       5        1   7.257203
# 5      0.065154  0.049344       6        1   7.108854
# 0      0.025824 -0.025667       7        1   7.092348
# 2      0.063037  0.045317       8        1   6.063185
# 8      0.054835  0.019734       9        1   4.507766
# 6      0.046187  0.011148      10        1   3.131594, topic_info=             Term        Freq       Total Category  logprob  loglift
# 45          covid  499.000000  499.000000  Default  30.0000  30.0000
# 78        vaccine  101.000000  101.000000  Default  29.0000  29.0000
# 6           false  148.000000  148.000000  Default  28.0000  28.0000
# 294         death   62.000000   62.000000  Default  27.0000  27.0000
# 22    coronavirus  100.000000  100.000000  Default  26.0000  26.0000
# ...           ...         ...         ...      ...      ...      ...
# 2018     claiming    1.283164    1.975123  Topic10  -5.2516   3.0323
# 1987        clean    1.278779    1.971583  Topic10  -5.2550   3.0307
# 1988      grocery    1.278779    1.971583  Topic10  -5.2550   3.0307
# 805           ask    1.265559    1.956273  Topic10  -5.2654   3.0281
# 768    foundation    1.183663    1.874416  Topic10  -5.3323   3.0039
#
# [350 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 2087      9  0.940374      aarp
# 2114      5  0.734699   aborted
# 163       6  0.949136   account
# 1383      9  0.839816  actually
# 407       4  0.912206       add
# ...     ...       ...       ...
# 779       6  0.962967     world
# 1390      4  0.942987     wrong
# 733       8  0.866248   wrongly
# 437       3  0.967768      year
# 436       5  0.817588       yet
#
# [325 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 4, 10, 5, 8, 6, 1, 3, 9, 7])

# %%
output = lda_model.show_topics(num_words=30)

# %%
output_df = pd.DataFrame()
for o in output:    
    d = {}
    topic_num = o[0]
    distribution = o[1]
    decimal_list = re.findall(r'\d+\.\d+', distribution)
    word_list = re.findall(r'"([^"]*)"', distribution)
    d["topic_" + str(topic_num + 1) + "_word"] = word_list
    d["topic_" + str(topic_num + 1) + "_dist"] =  decimal_list

    topic_df = pd.DataFrame(d)
    output_df = pd.concat([output_df, topic_df], axis=1)

output_df
# Out:
#        topic_1_word topic_1_dist topic_2_word topic_2_dist  topic_3_word  \
# 0          pandemic        0.058        covid        0.223       vaccine
# 1             cause        0.046        false        0.068    government
# 2              cure        0.042        claim        0.049        pfizer
# 3              home        0.035         mask        0.039  donald_trump
# 4               pay        0.024          say        0.037         state
# 5              bill        0.021         post        0.023          work
# 6        conspiracy        0.020     evidence        0.014    coronaviru
# 7              test        0.015          new        0.013       develop
# 8              blue        0.013        trump        0.013         fraud
# 9   tested_positive        0.013         case        0.012          turn
# 10              kit        0.008         wear        0.011   vaccination
# 11              tea        0.008      mislead        0.010         still
# 12          similar        0.008       health        0.009         plane
# 13             mean        0.007     hospital        0.007      untested
# 14              lie        0.007        tweet        0.007        kenyan
# 15         negative        0.007         hoax        0.007           ban
# 16         campaign        0.007       expert        0.006      conspire
# 17          endorse        0.006     stimulus        0.006     scientist
# 18             less        0.006         risk        0.006       natural
# 19            bonus        0.006      testing        0.006          also
# 20             deny        0.006       public        0.006        create
# 21             cost        0.006        check        0.005       wrongly
# 22            blame        0.006       letter        0.005          roll
# 23           herbal        0.006      prevent        0.005      planning
# 24           nearly        0.006        carry        0.005     recipient
# 25           reveal        0.006       almost        0.005        expect
# 26           remedy        0.005     official        0.004     injection
# 27             care        0.005         help        0.004     candidate
# 28            empty        0.005         back        0.004     available
# 29        falsehood        0.005         link        0.004     supporter
#
#    topic_3_dist  topic_4_word topic_4_dist     topic_5_word topic_5_dist  \
# 0         0.213   coronavirus        0.067            photo        0.044
# 1         0.034          test        0.039              old        0.029
# 2         0.020          make        0.023            wrong        0.028
# 3         0.019         viral        0.023              flu        0.027
# 4         0.019          take        0.021         lockdown        0.026
# 5         0.016           get        0.019             rate        0.025
# 6         0.014        doctor        0.018            image        0.024
# 7         0.013      facebook        0.018        bill_gate        0.020
# 8         0.010          news        0.016            video        0.019
# 9         0.010          stop        0.015          disease        0.018
# 10        0.009            go        0.015             face        0.017
# 11        0.009     infection        0.015            viral        0.015
# 12        0.009          post        0.015         survival        0.015
# 13        0.008         child        0.014           victim        0.014
# 14        0.008      positive        0.013          country        0.013
# 15        0.007       patient        0.013             show        0.013
# 16        0.007        relief        0.011          context        0.013
# 17        0.006         prove        0.010        face_mask        0.012
# 18        0.006          fact        0.009       comparison        0.011
# 19        0.006        school        0.009           police        0.010
# 20        0.006          cold        0.009        vaccinate        0.010
# 21        0.006         novel        0.008              add        0.010
# 22        0.006          hoax        0.008        statistic        0.009
# 23        0.006          tell        0.007            biden        0.009
# 24        0.006           say        0.007            spray        0.008
# 25        0.006           sex        0.007  social_distance        0.008
# 26        0.006      resident        0.007          suicide        0.007
# 27        0.006  social_media        0.007            break        0.007
# 28        0.006         covid        0.007          falsely        0.006
# 29        0.005     authority        0.006      legionnaire        0.006
#
#     topic_6_word topic_6_dist       topic_7_word topic_7_dist    topic_8_word  \
# 0         people        0.102                due        0.046           death
# 1          share        0.038               fund        0.034            fake
# 2           kill        0.036               food        0.027          spread
# 3     fact_check        0.035               call        0.019  misinformation
# 4         number        0.028               gate        0.018            plan
# 5           give        0.023             arrest        0.016         confirm
# 6     quarantine        0.022             charge        0.014         message
# 7          world        0.016               want        0.013        headline
# 8          issue        0.013              leave        0.012            lead
# 9     inaccurate        0.013               huge        0.011          crisis
# 10          many        0.012              close        0.011             yet
# 11      together        0.011            predict        0.011           force
# 12         fauci        0.011          appointee        0.009         compare
# 13       foreign        0.010              stamp        0.009          record
# 14        travel        0.010        withholding        0.009          advice
# 15         order        0.010                fax        0.009           board
# 16        system        0.009             exceed        0.009          debunk
# 17          scam        0.009            machine        0.009            true
# 18       account        0.008            recover        0.009      screenshot
# 19       website        0.008        contaminate        0.009         tourism
# 20           put        0.008            collect        0.008            shut
# 21         phone        0.008             refute        0.007            know
# 22       healthy        0.008           decision        0.007          detain
# 23  unemployment        0.007          gathering        0.007         aborted
# 24       tracing        0.007  conspiracy_theory        0.006            male
# 25       contact        0.007           claiming        0.005           fetus
# 26       wedding        0.007            grocery        0.005           reeve
# 27          seek        0.007              clean        0.005         distort
# 28          meme        0.006                ask        0.005          annual
# 29     community        0.006         foundation        0.005        analysis
#
#    topic_8_dist   topic_9_word topic_9_dist topic_10_word topic_10_dist
# 0         0.108            die        0.101         video         0.056
# 1         0.085       research        0.028        report         0.046
# 2         0.050          offer        0.026          show         0.044
# 3         0.020         infect        0.021         virus         0.043
# 4         0.019           free        0.019       receive         0.022
# 5         0.018         cancer        0.017          year         0.022
# 6         0.015           hand        0.012     circulate         0.022
# 7         0.013       election        0.012        online         0.019
# 8         0.013        declare        0.011       medical         0.018
# 9         0.012          story        0.011      outbreak         0.017
# 10        0.010          catch        0.009         photo         0.017
# 11        0.009        suggest        0.009         first         0.015
# 12        0.009    certificate        0.008          part         0.013
# 13        0.008       response        0.008         fight         0.012
# 14        0.008       actually        0.008       chinese         0.012
# 15        0.007      dangerous        0.008         month         0.011
# 16        0.007           need        0.008           eat         0.011
# 17        0.007         search        0.008        border         0.011
# 18        0.007       distinct        0.007       include         0.011
# 19        0.007      challenge        0.007      japanese         0.011
# 20        0.006     hypothesis        0.007         woman         0.011
# 21        0.006         matter        0.007     attribute         0.010
# 22        0.006           aarp        0.007     president         0.009
# 23        0.006            kid        0.007         visit         0.008
# 24        0.006            tie        0.007      document         0.008
# 25        0.006        suppose        0.006         right         0.008
# 26        0.006      guideline        0.006         truth         0.007
# 27        0.006          exist        0.006        happen         0.007
# 28        0.006  south_african        0.006          team         0.007
# 29        0.006    supermarket        0.006      immunity         0.007

# %%
data = df.fillna('')

# %%
data['Primary_Country'].value_counts()[:20].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Primary_Country'].value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['Motive']
# Out:
# 0                       Politics
# 1                           Fear
# 2                       Politics
# 3                           Fear
# 4                           Fear
#                   ...
# 1264           Downplay Severity
# 1265    Undermine target country
# 1266    Undermine target country
# 1267                        Fear
# 1268           Downplay Severity
# Name: Motive, Length: 1269, dtype: object

# %%
data.head()
# Out:
#                                          Reported_On Additional_Reporting  \
# 0  https://www.buzzfeednews.com/article/ryanhates...
# 1  https://twitter.com/Rangoli_A/status/122779241...
# 2  https://twitter.com/Woppa1Woppa/status/1220068...
# 3  https://twitter.com/FreddiGoldstein/status/123...
# 4  https://www.boomlive.in/health/hoax-alert-vira...
#
#                                      Retrieve_from_1 Retrieve_from_2  \
# 0  https://www.buzzfeednews.com/article/ryanhates...
# 1
# 2
# 3
# 4  https://www.boomlive.in/health/hoax-alert-vira...
#
#   Retrieve_from_3  Twitter_Reference  \
# 0                              False
# 1                               True
# 2                               True
# 3                               True
# 4                              False
#
#                                        Direct_Post_1 Direct_Post_2  \
# 0
# 1  https://twitter.com/Rangoli_A/status/122779241...
# 2  https://twitter.com/Woppa1Woppa/status/1220068...
# 3  https://twitter.com/FreddiGoldstein/status/123...
# 4
#
#   Direct_Post_3 Direct_Post_4  ...  \
# 0                              ...
# 1                              ...
# 2                              ...
# 3                              ...
# 4                              ...
#
#                                Narrative_Description ChainMsg_or_Email  \
# 0  Hindi language YouTube account saying COVID-19...             False
# 1  Twitter user posting a compilation video of pe...             False
# 2  Twitter user posting a video of a celebrity ea...             False
# 3       Chain message of NYPD containment responses.              True
# 4  Chain message of Indian Health Ministry respon...              True
#
#      Motive                                 Motive_Description  \
# 0  Politics  Efforts to spread false claims on the origins ...
# 1      Fear  Twitter user stoking fear among other users, s...
# 2  Politics  Twitter user discrediting Chinese-American pop...
# 3      Fear  Chain message spread to stoke fear among Ameri...
# 4      Fear  Chain message spread to stoke fear among India...
#
#              Source Source_Description Distrib_Channel     Misinfo_Type  \
# 0  Individual actor     General public         Youtube       Conspiracy
# 1  Individual actor     General public         Twitter  False reporting
# 2  Individual actor     General public         Twitter  False reporting
# 3  Individual actor     General public         Twitter  False reporting
# 4  Individual actor     General public        Facebook  False reporting
#
#                              Key_Words  \
# 0         Coronavirus, India, bat soup
# 1         Coronavirus, China, shooting
# 2  Coronavirus, Chinese food, bat soup
# 3  Coronavirus, NYPD, containment zone
# 4  Coronavirus, India, travel advisory
#
#                                              Summary
# 0  Hindi language Youtube account suggesting COVI...
# 1  Tweet with video showing "people getting shot ...
# 2  Video of an individual eating a delicacy, and ...
# 3  Tweet with a screenshot of chain message sugge...
# 4  WhatsApp chain message circulating among India...
#
# [5 rows x 27 columns]

# %%
import seaborn as sns

sns.heatmap(pd.crosstab(df.Primary_Country, df.Motive))
# Out:
# <AxesSubplot:xlabel='Motive', ylabel='Primary_Country'>
