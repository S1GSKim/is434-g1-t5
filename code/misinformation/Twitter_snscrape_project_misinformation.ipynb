# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# users = ['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph'])
df_abc = pd.read_csv('ABC.csv')
df_foxnews = pd.read_csv('FoxNews.csv')
df_msnbc = pd.read_csv('MSNBC.csv')
df_nbcnews = pd.read_csv('NBCNews.csv')
df_usatoday = pd.read_csv('USATODAY.csv')
df_wsj = pd.read_csv('WSJ.csv')
df_washingtonpost = pd.read_csv('washingtonpost.csv')
df_buzzfeed = pd.read_csv('BuzzFeed.csv')
df_voxdotcom = pd.read_csv('voxdotcom.csv')
df_mailonline = pd.read_csv('MailOnline.csv')
df_dailyexpress = pd.read_csv('Daily_Express.csv')
df_telegraph = pd.read_csv('Telegraph.csv')

df_list = [df_abc, df_foxnews, df_msnbc, df_nbcnews, df_usatoday, df_wsj, df_washingtonpost, df_buzzfeed, df_voxdotcom, df_mailonline, df_dailyexpress, df_telegraph]

df_final=pd.concat(df_list, ignore_index=True)
df_final.head(30)
# Out:
#                      Datetime  retweetCount  \
# 0   2021-02-27 23:33:13+00:00           151
# 1   2021-02-27 22:31:48+00:00            43
# 2   2021-02-27 20:30:00+00:00             6
# 3   2021-02-27 18:32:27+00:00           107
# 4   2021-02-27 16:37:48+00:00            24
# 5   2021-02-27 14:50:56+00:00            93
# 6   2021-02-27 14:15:35+00:00           135
# 7   2021-02-27 10:26:23+00:00            28
# 8   2021-02-27 09:50:18+00:00            36
# 9   2021-02-27 08:56:07+00:00            29
# 10  2021-02-27 07:14:53+00:00           206
# 11  2021-02-27 04:51:02+00:00            51
# 12  2021-02-26 22:10:41+00:00           388
# 13  2021-02-26 21:59:52+00:00            14
# 14  2021-02-26 21:10:51+00:00            24
# 15  2021-02-26 19:47:40+00:00            26
# 16  2021-02-26 19:31:09+00:00            17
# 17  2021-02-26 15:32:49+00:00            19
# 18  2021-02-26 15:12:22+00:00            51
# 19  2021-02-26 12:49:08+00:00            22
# ...

# %%
df_final.shape
# Out:
# (11076, 6)

# %%
### MODEL FOR DETECTING FAKE NEWS
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df_fake = pd.read_csv("Fake.csv")
df_true = pd.read_csv("True.csv")

# %%
df_fake.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake["class"] = 0
df_true["class"] = 1

# %%
df_fake.shape, df_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
df_fake_manual_testing = df_fake.tail(10)
for i in range(23480,23470,-1):
    df_fake.drop([i], axis = 0, inplace = True)
df_true_manual_testing = df_true.tail(10)
for i in range(21416,21406,-1):
    df_true.drop([i], axis = 0, inplace = True)

# %%
df_fake.shape, df_true.shape
# Out:
# ((23471, 5), (21407, 5))

# %%
df_fake_manual_testing["class"] = 0
df_true_manual_testing["class"] = 1
# Out:
# <ipython-input-12-3aaf8ec2aad1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fake_manual_testing["class"] = 0
# <ipython-input-12-3aaf8ec2aad1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_true_manual_testing["class"] = 1

# %%
df_fake_manual_testing.head(10)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
df_true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
df_manual_testing = pd.concat([df_fake_manual_testing,df_true_manual_testing], axis = 0)
df_manual_testing.to_csv("manual_testing.csv")

# %%
df_marge = pd.concat([df_fake, df_true], axis =0 )
df_marge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
df_marge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
df = df_marge.drop(["title", "subject","date"], axis = 1)

# %%
df.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
df = df.sample(frac = 1)

# %%
df.head()
# Out:
#                                                     text  class
# 19176  MOSCOW (Reuters) - Russia s Defence Ministry s...      1
# 451    While in the United States, Special Investigat...      0
# 21900   About 2,000 of the emails I got were of suppo...      0
# 17672  SOFIA (Reuters) - Couples lining up to face ea...      1
# 14133  BRUSSELS (Reuters) - A summit of euro zone lea...      1

# %%
df.reset_index(inplace = True)
df.drop(["index"], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
df.head()
# Out:
#                                                 text  class
# 0  MOSCOW (Reuters) - Russia s Defence Ministry s...      1
# 1  While in the United States, Special Investigat...      0
# 2   About 2,000 of the emails I got were of suppo...      0
# 3  SOFIA (Reuters) - Couples lining up to face ea...      1
# 4  BRUSSELS (Reuters) - A summit of euro zone lea...      1

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text

# %%
df["text"] = df["text"].apply(wordopt)

# %%
x = df["text"]
y = df["class"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test, y_test)
# Out:
# 0.9947415329768271

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5903
#            1       1.00      0.99      0.99      5317
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
#df_final["Text"] = df_final["Text"].apply(wordopt)

# %%
def output_lable(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt) 
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_DT = DT.predict(new_xv_test)

    return output_lable(pred_DT[0])

# %%
df_final = df_final.dropna()

# %%
df_final['truthfulness']='0'

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10993 entries, 0 to 11075
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Datetime      10993 non-null  object
#  1   retweetCount  10993 non-null  int64
#  2   Text          10993 non-null  object
#  3   Username      10993 non-null  object
#  4   Keywords      10993 non-null  object
#  5   truthfulness  10993 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 601.2+ KB

# %%
for index, row in df_final.iterrows():
    if manual_testing(row['Text'])=='Fake News':
        df_final.at[index,'truthfulness']='fake'
    else:
        df_final.at[index,'truthfulness']='true'

# %%
# users = ['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph']

# %%
print("Percentage of fake news for ABC : "+ str(df_final[df_final['Username']=='ABC']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for FoxNews : "+ str(df_final[df_final['Username']=='FoxNews']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for MSNBC : "+ str(df_final[df_final['Username']=='MSNBC']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for NBCNews : "+ str(df_final[df_final['Username']=='NBCNews']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for USATODAY : "+ str(df_final[df_final['Username']=='USATODAY']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for WSJ : "+ str(df_final[df_final['Username']=='WSJ']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for washingtonpost : "+ str(df_final[df_final['Username']=='washingtonpost']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for BuzzFeed : "+ str(df_final[df_final['Username']=='BuzzFeed']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for voxdotcom : "+ str(df_final[df_final['Username']=='voxdotcom']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for MailOnline : "+ str(df_final[df_final['Username']=='MailOnline']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for Daily_Expresst : "+ str(df_final[df_final['Username']=='Daily_Express']['truthfulness'].value_counts('fake').iloc[0]))
print("Percentage of fake news for Telegraph : "+ str(df_final[df_final['Username']=='Telegraph']['truthfulness'].value_counts('fake').iloc[0]))
# Out:
# Percentage of fake news for ABC : 0.940427993059572
# Percentage of fake news for FoxNews : 0.9701754385964912
# Percentage of fake news for MSNBC : 0.9768185451638689
# Percentage of fake news for NBCNews : 0.9657772621809745
# Percentage of fake news for USATODAY : 0.98565965583174
# Percentage of fake news for WSJ : 0.997134670487106
# Percentage of fake news for washingtonpost : 0.9769452449567724
# Percentage of fake news for BuzzFeed : 1.0
# Percentage of fake news for voxdotcom : 0.9896907216494846
# Percentage of fake news for MailOnline : 0.9466357308584686
# Percentage of fake news for Daily_Expresst : 0.9957081545064378
# Percentage of fake news for Telegraph : 0.9786585365853658

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
newsMedia=pd.Series(['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph'])

# %%
x = pd.Series(['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph'])

# %%
deaccuracy=pd.Series([df_final[df_final['Username']=='ABC']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='FoxNews']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='MSNBC']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='NBCNews']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='USATODAY']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='WSJ']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='washingtonpost']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='BuzzFeed']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='voxdotcom']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='MailOnline']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='Daily_Express']['truthfulness'].value_counts('fake').iloc[0],df_final[df_final['Username']=='Telegraph']['truthfulness'].value_counts('fake').iloc[0]])

# %%
# Figure Size
plt.rcParams.update({'font.size': 30})
fig, ax = plt.subplots(figsize =(15, 9))
 
# Horizontal Bar Plot
ax.barh(newsMedia, deaccuracy,color=['#ff0000', '#ff8000','#ffff00','#80ff00','#00ff00','#00ff80','#00ffff','#0080ff','#0000ff','#8000ff','#ff00ff','#ff0080'])

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title("News Medias' Covid-19 Fake News Accuracy",
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.xlim([0.9, 1.0])
plt.show()

# %% [markdown]
# # WordCloud of Fake News dataset

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib.pyplot as plt2
text = " ".join(i for i in df_final[df_final['truthfulness']=='fake'].Text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt2.figure( figsize=(15,10))
plt2.imshow(wordcloud, interpolation='bilinear')
plt2.axis("off")
plt2.show()
