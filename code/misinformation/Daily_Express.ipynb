# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# users = ['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph'])
import re
from newspaper import Article
users = ['Daily_Express']
filters = ['Covid-19 since:2020-12-01', 'until:2021-02-28']
from_filters = []
for user in users:
    from_filters.append(f'from:{user}')
filters.append(' OR '.join(from_filters))
tweets = list(sntwitter.TwitterSearchScraper(' '.join(filters)).get_items())
print(len(tweets))
tweet_list=[]
count=1
for tweet in tweets:
    tweetContent=tweet.rawContent
    try:
        url = re.search("(?P<url>https?://[^\s]+)", tweetContent).group("url")
        print(url)
        count+=1
        try:
            toi_article = Article(url, language="en") # en for English

            #To download the article
            toi_article.download()

            #To parse the article
            toi_article.parse()

            #To perform natural language processing ie..nlp
            toi_article.nlp()

            tweet_list.append([tweet.date, tweet.retweetCount, toi_article.text, tweet.user.username, toi_article.keywords])
            print("Able to Scrape article"+str(count))
        except:
            tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
            print("Unable to Scrape article"+str(count))
    except:
        tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
        print("Unable to Scrape article"+str(count))
df_first = pd.DataFrame(tweet_list, columns=['Datetime','retweetCount','Text', 'Username','Keywords'])
df_first.drop_duplicates(subset='Text', keep="last")
df_first.head(30)
# Out:
# 190
# https://t.co/5BtrjSUAoJ
# Able to Scrape article2
# https://t.co/5BtrjSCZxb
# Able to Scrape article3
# https://t.co/uj4UZi8xZR
# Able to Scrape article4
# https://t.co/ODimkzqFIV
# Able to Scrape article5
# https://t.co/neIsmhWqkK
# Able to Scrape article6
# https://t.co/LSiK4DgWvO
# Able to Scrape article7
# https://t.co/LSiK4DyxUo
# Able to Scrape article8
# https://t.co/9dNomnTbAf
# Able to Scrape article9
# https://t.co/J6wu7HcNij
# Able to Scrape article10
# https://t.co/J6wu7HuoGT
# Able to Scrape article11
# https://t.co/9dNomoaMYP
# Able to Scrape article12
# https://t.co/J6wu7HcNij
# Able to Scrape article13
# https://t.co/J6wu7HuoGT
# Able to Scrape article14
# https://t.co/J6wu7HuoGT
# Able to Scrape article15
# https://t.co/J6wu7HuoGT
# Able to Scrape article16
# https://t.co/oyO530hlaf
# Able to Scrape article17
# https://t.co/NrE4m913n8
# Able to Scrape article18
# https://t.co/KJslq0g4kP
# Able to Scrape article19
# https://t.co/QJ0RC5LbAq
# Able to Scrape article20
# https://t.co/QJ0RC5LbAq
# Able to Scrape article21
# https://t.co/I3pmI9BQIt
# Able to Scrape article22
# https://t.co/7NLPIGlyG5
# Able to Scrape article23
# https://t.co/XfUsNEkAvP
# Able to Scrape article24
# https://t.co/UQGENsQR2E
# Able to Scrape article25
# https://t.co/CuuKCF3GYC
# Able to Scrape article26
# https://t.co/0nLcY7Kknu
# Able to Scrape article27
# https://t.co/6oexNgnyic
# Able to Scrape article28
# https://t.co/6oexNgnyic
# Able to Scrape article29
# https://t.co/MZFdpvtlsS
# Able to Scrape article30
# https://t.co/LBl6YhHBEw
# Able to Scrape article31
# https://t.co/hanB2tTPWv
# Able to Scrape article32
# https://t.co/xXGnmOMJxy
# Able to Scrape article33
# https://t.co/xXGnmOMJxy
# Able to Scrape article34
# https://t.co/yB5S7Pa0mP
# Able to Scrape article35
# https://t.co/49H0XgxDUj
# Able to Scrape article93
# https://t.co/M5XiKVMWhp
# Able to Scrape article94
# https://t.co/M5XiKW4xFZ
# Able to Scrape article95
# https://t.co/q1dAeXuPtv
# Able to Scrape article96
# https://t.co/TQrBLx0u68
# Able to Scrape article97
# https://t.co/cy8JCNMxBh
# Able to Scrape article98
# https://t.co/puFftKDlB7
# Able to Scrape article99
# https://t.co/j8fieUaf65
# Able to Scrape article100
# https://t.co/j8fieUaf65
# Able to Scrape article101
# https://t.co/j8fieUaf65
# Able to Scrape article102
# https://t.co/j8fieUrQuF
# Able to Scrape article103
# https://t.co/58IUv1CmW6
# Able to Scrape article104
# https://t.co/NreuncKR9Y
# Able to Scrape article105
# https://t.co/Nreund2syy
# Able to Scrape article106
# https://t.co/FCyEGHUNJj
# Able to Scrape article107
# https://t.co/FCyEGIcp7T
# Able to Scrape article108
# https://t.co/TQrBLx0u68
# Able to Scrape article109
# https://t.co/HLzrZHq7Fr
# Able to Scrape article110
# https://t.co/87lAjCIT7k
# Able to Scrape article111
# https://t.co/QtyBWAaIdt
# Able to Scrape article112
# https://t.co/MGkZMvBI2a
# Able to Scrape article113
# https://t.co/vbLYq1ciO4
# Able to Scrape article114
# https://t.co/uBcHzQBo8f
# Able to Scrape article115
# https://t.co/uBcHzQBo8f
# Able to Scrape article116
# https://t.co/nHorhurOSX
# Able to Scrape article117
# https://t.co/uBcHzQSZwP
# Able to Scrape article118
# https://t.co/MGkZMvk6DA
# Able to Scrape article119
# https://t.co/MGkZMvBI2a
# Able to Scrape article120
# https://t.co/VOrvNqk1fE
# Able to Scrape article121
# https://t.co/Sry5ijGgEN
# Able to Scrape article122
# https://t.co/HpCcM2uUNM
# Able to Scrape article123
# https://t.co/dDnW8iaS6t
# Able to Scrape article124
# https://t.co/Sry5ijGgEN
# Able to Scrape article125
# https://t.co/HpCcM2Mwcm
# Able to Scrape article126
# https://t.co/HpCcM2Mwcm
# Able to Scrape article127
# https://t.co/dDnW8istv3
# Able to Scrape article128
# https://t.co/K4ZwgQE1R5
# Able to Scrape article129
# https://t.co/X14ns1B9TC
# Able to Scrape article130
# https://t.co/GGEC2JuMut
# Able to Scrape article131
# https://t.co/N6L6MAyoYv
# Able to Scrape article132
# https://t.co/PkWsFKx7IL
# Able to Scrape article133
# https://t.co/PkWsFKx7IL
# Able to Scrape article134
# https://t.co/PkWsFKx7IL
# Able to Scrape article135
# https://t.co/NAJKE1Zmfj
# Able to Scrape article136
# https://t.co/Jh5tCbu33n
# Able to Scrape article137
# https://t.co/8KSifjvSc0
# Able to Scrape article138
# https://t.co/ZemQcSvlbo
# Able to Scrape article139
# https://t.co/ZemQcSMWzY
# Able to Scrape article140
# https://t.co/uXnsrBixRH
# Able to Scrape article141
# https://t.co/fhxOW0om2o
# Able to Scrape article142
# https://t.co/fhxOW06LaQ
# Able to Scrape article143
# https://t.co/uXnsrBixRH
# Able to Scrape article144
# https://t.co/eax9Eug3BL
# Able to Scrape article145
# https://t.co/uXnsrBixRH
# Able to Scrape article146
# https://t.co/fhxOW0om2o
# Able to Scrape article147
# https://t.co/IgLF70wsAy
# Able to Scrape article148
# https://t.co/PLi1eZF4Gk
# Able to Scrape article149
# 18 2021-02-18 18:10:00+00:00             2
# 19 2021-02-18 18:05:37+00:00             7
# 20 2021-02-15 22:43:55+00:00             0
# 21 2021-02-13 16:13:26+00:00             2
# 22 2021-02-12 10:21:30+00:00             2
# 23 2021-02-12 09:06:40+00:00             2
# 24 2021-02-11 09:05:00+00:00             3
# 25 2021-02-10 22:38:32+00:00            21
# 26 2021-02-09 21:00:00+00:00             2
# 27 2021-02-09 17:00:00+00:00             1
# 28 2021-02-09 16:02:08+00:00             3
# 29 2021-02-09 09:01:00+00:00             3
#
#                                                  Text       Username  \
# 0   Brexit: Boris Johnson praises work of negotiat...  Daily_Express
# 1   Brexit: Boris Johnson praises work of negotiat...  Daily_Express
# 2   Boris Johnson says the 'strain is colossal' on...  Daily_Express
# 3   JavaScript is not available.\n\nWe’ve detected...  Daily_Express
# 4   Vaccination passport ‘almost exists already’ s...  Daily_Express
# 5   Vaccine: France 'did not block distribution' c...  Daily_Express
# 6   Vaccine: France 'did not block distribution' c...  Daily_Express
# 7   As Dr Chris explained to Holly and Phil, nasal...  Daily_Express
# 8   Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 9   Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 10  As Dr Chris explained to Holly and Phil, nasal...  Daily_Express
# 11  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 12  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 13  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 14  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 15  Patrick Vallance explains ‘increased risk’ of ...  Daily_Express
# 16  Jo Whiley provides update on her sister’s batt...  Daily_Express
# 17  Ebola: Guinea Health Agency head declares a 'p...  Daily_Express
# 18  Nigerian variant in UK could be resistant to v...  Daily_Express
# 19  Nigerian variant in UK could be resistant to v...  Daily_Express
# 20  Vaccine: Hancock urges care home staff to come...  Daily_Express
# 21  The Apple Watch can be used to detect a positi...  Daily_Express
# 22  Oxford AstraZeneca vaccine side effects - what...  Daily_Express
# 23  The Foreign, Commonwealth and Development Offi...  Daily_Express
# 24  Coronavirus new strain symptoms: 12 symptoms t...  Daily_Express
# 25  WHO discuss coronavirus origin mission finding...  Daily_Express
# 26  'Beautiful' Benidorm 'gets bad press' for rowd...  Daily_Express
# 27  'Beautiful' Benidorm 'gets bad press' for rowd...  Daily_Express
# 28  Coronavirus symptoms can begin between two and...  Daily_Express
# 29  'Beautiful' Benidorm 'gets bad press' for rowd...  Daily_Express
#
#                                              Keywords
# 0   [european, urged, red, britain, tape, eu, econ...
# 1   [european, urged, red, britain, tape, eu, econ...
# 2   [outrage, struggle, 25k, covid, nhs, ppe, vacc...
# 3   [twittercom, enable, switch, list, disabled, j...
# 4   [erupts, vaccination, exist, point, audience, ...
# 5   [world, beaune, situation, admits, france, del...
# 6   [world, beaune, situation, admits, france, del...
# 7   [chris, coronavirus, nasal, hay, help, yearof,...
# 8   [venues, pubs, certificates, review, status, l...
# 9   [venues, pubs, certificates, review, status, l...
# 10  [chris, coronavirus, nasal, hay, help, yearof,...
# 11  [venues, pubs, certificates, review, status, l...
# 12  [venues, pubs, certificates, review, status, l...
# 13  [venues, pubs, certificates, review, status, l...
# 14  [venues, pubs, certificates, review, status, l...
# 15  [warned, huge, deaths, lockdown, cases, covid,...
# 16  [restrained, battled, frances, jo, vaccine, ox...
# 17  [world, joe, health, ebola, outbreak, guinea, ...
# 18  [variant, theres, uniquethey, coronavirus, yet...
# 19  [variant, theres, uniquethey, coronavirus, yet...
# 20  [vaccines, debunked, covid, jab, experts, vacc...
# 21  [months, swab, researchers, watch, week, posit...
# 22  [recognised, strongly, covid, coronavirus, los...
# 23  [world, vaccinated, spain, expats, country, co...
# 24  [sign, burns, red, hands, radiation, covid, co...
# 25  [sarscov2, cases, unlikely, thailand, coronavi...
# 26  [non, strengthen, taking, arrivals, starting, ...
# 27  [non, strengthen, taking, arrivals, starting, ...
# 28  [warned, public, health, variants, loss, coron...
# 29  [think, vaccine, thanks, uk, rate, growth, cor...

# %%
# users = ['ABC','CBSNews','CNN','nytimes','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost','politico','CNET']
import re
from newspaper import Article
users = ['Daily_Express']
filters = ['Covid-19 since:2022-01-01', 'until:2022-03-31']
from_filters = []
for user in users:
    from_filters.append(f'from:{user}')
filters.append(' OR '.join(from_filters))
tweets = list(sntwitter.TwitterSearchScraper(' '.join(filters)).get_items())
print(len(tweets))
tweet_list=[]
count=1
for tweet in tweets:
    tweetContent=tweet.rawContent
    try:
        url = re.search("(?P<url>https?://[^\s]+)", tweetContent).group("url")
        print(url)
        count+=1
        try:
            toi_article = Article(url, language="en") # en for English

            #To download the article
            toi_article.download()

            #To parse the article
            toi_article.parse()

            #To perform natural language processing ie..nlp
            toi_article.nlp()

            tweet_list.append([tweet.date, tweet.retweetCount, toi_article.text, tweet.user.username, toi_article.keywords])
            print("Able to Scrape article"+str(count))
        except:
            tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
            print("Unable to Scrape article"+str(count))
    except:
        tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
        print("Unable to Scrape article"+str(count))
df_second = pd.DataFrame(tweet_list, columns=['Datetime','retweetCount','Text', 'Username','Keywords'])
df_second.drop_duplicates(subset='Text', keep="last")
df_second.head()
# Out:
# 43
# https://t.co/MmlamvQmDv
# Able to Scrape article2
# https://t.co/MmlamvQmDv
# Able to Scrape article3
# https://t.co/MmlamvyLLX
# Able to Scrape article4
# https://t.co/3MRrWcJdOY
# Able to Scrape article5
# https://t.co/3MRrWcJdOY
# Able to Scrape article6
# https://t.co/QyxNblTNEK
# Able to Scrape article7
# https://t.co/UETciE2od7
# Able to Scrape article8
# https://t.co/UETciE2od7
# Able to Scrape article9
# https://t.co/j7JgWybBwK
# Able to Scrape article10
# https://t.co/ZIZfZfOopS
# Able to Scrape article11
# https://t.co/ZIZfZg5Zhq
# Able to Scrape article12
# https://t.co/ZIZfZfOopS
# Able to Scrape article13
# https://t.co/ZIZfZg5Zhq
# Able to Scrape article14
# https://t.co/KAb9OwgCLi
# Able to Scrape article15
# https://t.co/Bh4eHY4K8W
# Able to Scrape article16
# https://t.co/VVecoJ61d2
# Able to Scrape article17
# https://t.co/C2Blkp70K2
# Able to Scrape article18
# https://t.co/2QIsxjI2iC
# Able to Scrape article19
# https://t.co/jfXuO9eOiF
# Able to Scrape article20
# Unable to Scrape article20
# https://t.co/nyfPyXuAfe
# Able to Scrape article21
# https://t.co/Bh4eHY4K8W
# Able to Scrape article22
# https://t.co/nyfPyXcZnG
# Able to Scrape article23
# https://t.co/EvUNmTJOHF
# Able to Scrape article24
# https://t.co/364CszsWML
# Able to Scrape article25
# https://t.co/Bh4eHYmlxw
# Able to Scrape article26
# https://t.co/K7ezzFMqb9
# Able to Scrape article27
# https://t.co/JBrvEnDgH2
# Able to Scrape article28
# https://t.co/JBrvEnUS5C
# Able to Scrape article29
# https://t.co/j9CcBH5hOu
# Able to Scrape article30
# https://t.co/H2RB9Cys8u
# Able to Scrape article31
# https://t.co/9TO8X4wWXd
# Able to Scrape article32
# https://t.co/ngYUrlEven
# Able to Scrape article33
# https://t.co/ngYUrlW65V
# Able to Scrape article34
# https://t.co/ngYUrlEven
# Able to Scrape article35
# https://t.co/Db7i1FiXZg
# Able to Scrape article36
# https://t.co/XzGICxrsC2
# Able to Scrape article37
# https://t.co/MM5lzv4yC1
# Able to Scrape article38
# Unable to Scrape article38
# https://t.co/HJe9eevkUe
# Able to Scrape article39
# https://t.co/1PIz4ALZJM
# Able to Scrape article40
# https://t.co/lPW6qJXrNR
# Able to Scrape article41
# https://t.co/FDV09MSGEf
# Able to Scrape article42
#                    Datetime  retweetCount  \
# 0 2022-03-24 06:01:00+00:00             2
# 1 2022-03-23 08:57:00+00:00             0
# 2 2022-03-23 08:05:57+00:00             1
# 3 2022-03-01 09:01:00+00:00             1
# 4 2022-02-28 13:36:00+00:00             1
#
#                                                 Text       Username  \
# 0  Susanna Reid pointed out it was "extraordinary...  Daily_Express
# 1  Susanna Reid pointed out it was "extraordinary...  Daily_Express
# 2  Susanna Reid pointed out it was "extraordinary...  Daily_Express
# 3  Kate Garraway feels 'positive' as she gives up...  Daily_Express
# 4  Kate Garraway feels 'positive' as she gives up...  Daily_Express
#
#                                             Keywords
# 0  [host, death, lockdown, backlash, cases, hilar...
# 1  [host, death, lockdown, backlash, cases, hilar...
# 2  [host, death, lockdown, backlash, cases, hilar...
# 3  [kate, derek, love, im, zoe, dereks, covid, po...
# 4  [kate, derek, love, im, zoe, dereks, covid, po...

# %%
df_final=pd.concat([df_first, df_second], ignore_index=True)
df_final.head(30)
# Out:
#                     Datetime  retweetCount  \
# 0  2021-02-26 20:00:01+00:00             2
# 1  2021-02-26 17:51:57+00:00             1
# 2  2021-02-26 15:00:01+00:00             3
# 3  2021-02-26 12:03:00+00:00             0
# 4  2021-02-26 08:17:32+00:00             0
# 5  2021-02-24 20:30:00+00:00             1
# 6  2021-02-24 18:33:05+00:00             1
# 7  2021-02-23 13:37:00+00:00             3
# 8  2021-02-23 11:38:00+00:00             0
# 9  2021-02-23 11:19:28+00:00             2
# 10 2021-02-23 11:17:15+00:00             1
# 11 2021-02-23 10:31:00+00:00             0
# 12 2021-02-23 10:12:08+00:00             2
# 13 2021-02-23 09:18:00+00:00             1
# 14 2021-02-23 08:59:04+00:00             0
# 15 2021-02-22 15:54:27+00:00             1
# 16 2021-02-21 11:34:00+00:00             0
# 17 2021-02-19 19:33:50+00:00             2
# 18 2021-02-18 18:10:00+00:00             2
# 19 2021-02-18 18:05:37+00:00             7
# 20 2021-02-15 22:43:55+00:00             0
# 21 2021-02-13 16:13:26+00:00             2
# 22 2021-02-12 10:21:30+00:00             2
# 23 2021-02-12 09:06:40+00:00             2
# 24 2021-02-11 09:05:00+00:00             3
# 25 2021-02-10 22:38:32+00:00            21
# 26 2021-02-09 21:00:00+00:00             2
# 27 2021-02-09 17:00:00+00:00             1
# 28 2021-02-09 16:02:08+00:00             3
# 29 2021-02-09 09:01:00+00:00             3
#
#                                                  Text       Username  \
# 0   Brexit: Boris Johnson praises work of negotiat...  Daily_Express
# 1   Brexit: Boris Johnson praises work of negotiat...  Daily_Express
# 2   Boris Johnson says the 'strain is colossal' on...  Daily_Express
# 3   JavaScript is not available.\n\nWe’ve detected...  Daily_Express
# 4   Vaccination passport ‘almost exists already’ s...  Daily_Express
# 5   Vaccine: France 'did not block distribution' c...  Daily_Express
# 6   Vaccine: France 'did not block distribution' c...  Daily_Express
# 7   As Dr Chris explained to Holly and Phil, nasal...  Daily_Express
# 8   Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 9   Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 10  As Dr Chris explained to Holly and Phil, nasal...  Daily_Express
# 11  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 12  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 13  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 14  Vaccine passports are ‘bad idea’ says Tory MP ...  Daily_Express
# 15  Patrick Vallance explains ‘increased risk’ of ...  Daily_Express
# 16  Jo Whiley provides update on her sister’s batt...  Daily_Express
# 17  Ebola: Guinea Health Agency head declares a 'p...  Daily_Express
# 18  Nigerian variant in UK could be resistant to v...  Daily_Express
# 19  Nigerian variant in UK could be resistant to v...  Daily_Express
# 20  Vaccine: Hancock urges care home staff to come...  Daily_Express
# 21  The Apple Watch can be used to detect a positi...  Daily_Express
# 22  Oxford AstraZeneca vaccine side effects - what...  Daily_Express
# 23  The Foreign, Commonwealth and Development Offi...  Daily_Express
# 24  Coronavirus new strain symptoms: 12 symptoms t...  Daily_Express
# 25  WHO discuss coronavirus origin mission finding...  Daily_Express
# 26  'Beautiful' Benidorm 'gets bad press' for rowd...  Daily_Express
# 27  'Beautiful' Benidorm 'gets bad press' for rowd...  Daily_Express
# 28  Coronavirus symptoms can begin between two and...  Daily_Express
# 29  'Beautiful' Benidorm 'gets bad press' for rowd...  Daily_Express
#
#                                              Keywords
# 0   [european, urged, red, britain, tape, eu, econ...
# 1   [european, urged, red, britain, tape, eu, econ...
# 2   [outrage, struggle, 25k, covid, nhs, ppe, vacc...
# 3   [twittercom, enable, switch, list, disabled, j...
# 4   [erupts, vaccination, exist, point, audience, ...
# 5   [world, beaune, situation, admits, france, del...
# 6   [world, beaune, situation, admits, france, del...
# 7   [chris, coronavirus, nasal, hay, help, yearof,...
# 8   [venues, pubs, certificates, review, status, l...
# 9   [venues, pubs, certificates, review, status, l...
# 10  [chris, coronavirus, nasal, hay, help, yearof,...
# 11  [venues, pubs, certificates, review, status, l...
# 12  [venues, pubs, certificates, review, status, l...
# 13  [venues, pubs, certificates, review, status, l...
# 14  [venues, pubs, certificates, review, status, l...
# 15  [warned, huge, deaths, lockdown, cases, covid,...
# 16  [restrained, battled, frances, jo, vaccine, ox...
# 17  [world, joe, health, ebola, outbreak, guinea, ...
# 18  [variant, theres, uniquethey, coronavirus, yet...
# 19  [variant, theres, uniquethey, coronavirus, yet...
# 20  [vaccines, debunked, covid, jab, experts, vacc...
# 21  [months, swab, researchers, watch, week, posit...
# 22  [recognised, strongly, covid, coronavirus, los...
# 23  [world, vaccinated, spain, expats, country, co...
# 24  [sign, burns, red, hands, radiation, covid, co...
# 25  [sarscov2, cases, unlikely, thailand, coronavi...
# 26  [non, strengthen, taking, arrivals, starting, ...
# 27  [non, strengthen, taking, arrivals, starting, ...
# 28  [warned, public, health, variants, loss, coron...
# 29  [think, vaccine, thanks, uk, rate, growth, cor...

# %%
df_final['truthfulness']='0'

# %%
df_final.to_csv('Daily_Express.csv', encoding='utf-8', index=False)
