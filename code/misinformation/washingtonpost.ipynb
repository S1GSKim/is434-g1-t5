# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# users = ['ABC','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost', 'BuzzFeed', 'voxdotcom', 'MailOnline', 'Daily_Express','Telegraph'])
import re
from newspaper import Article
users = ['washingtonpost']
filters = ['Covid-19 since:2020-12-01', 'until:2021-02-28']
from_filters = []
for user in users:
    from_filters.append(f'from:{user}')
filters.append(' OR '.join(from_filters))
tweets = list(sntwitter.TwitterSearchScraper(' '.join(filters)).get_items())
print(len(tweets))
tweet_list=[]
count=1
for tweet in tweets:
    tweetContent=tweet.rawContent
    try:
        url = re.search("(?P<url>https?://[^\s]+)", tweetContent).group("url")
        print(url)
        count+=1
        try:
            toi_article = Article(url, language="en") # en for English

            #To download the article
            toi_article.download()

            #To parse the article
            toi_article.parse()

            #To perform natural language processing ie..nlp
            toi_article.nlp()

            tweet_list.append([tweet.date, tweet.retweetCount, toi_article.text, tweet.user.username, toi_article.keywords])
            print("Able to Scrape article"+str(count))
        except:
            tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
            print("Unable to Scrape article"+str(count))
    except:
        tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
        print("Unable to Scrape article"+str(count))
df_first = pd.DataFrame(tweet_list, columns=['Datetime','retweetCount','Text', 'Username','Keywords'])
df_first.drop_duplicates(subset='Text', keep="last")
df_first.head(30)
# Out:
# 159
# https://t.co/qfgnoetiFv
# Able to Scrape article2
# https://t.co/IEq5T7fvnY
# Able to Scrape article3
# https://t.co/9jki6EwyG1
# Able to Scrape article4
# https://t.co/m8L4MyLlgV
# Able to Scrape article5
# https://t.co/s2YF3MyGts
# Able to Scrape article6
# https://t.co/5lJLA1rvrE
# Able to Scrape article7
# https://t.co/feTL2BwwIK
# Able to Scrape article8
# https://t.co/el4eg3wRD3
# Able to Scrape article9
# https://t.co/XlLzYE7WlL
# Able to Scrape article10
# https://t.co/QjapvINB1H
# Able to Scrape article11
# https://t.co/WhUUmmNTX6
# Able to Scrape article12
# https://t.co/8ezhdhg1KS
# Able to Scrape article13
# https://t.co/AU7UCGTDZz
# Able to Scrape article14
# https://t.co/uzONLEnkJp
# Able to Scrape article15
# https://t.co/WUh055bvdH
# Able to Scrape article16
# https://t.co/PR6hFHDnxP
# Able to Scrape article17
# https://t.co/tSbLshSPZd
# Able to Scrape article18
# https://t.co/tsTHoqZJst
# Able to Scrape article19
# https://t.co/iF3U26hSKD
# Able to Scrape article20
# https://t.co/T1taabXw7I
# Able to Scrape article21
# https://t.co/PafH5F21IZ
# Able to Scrape article22
# https://t.co/OBq3uQchpU
# Able to Scrape article23
# https://t.co/YfbjrSZ7Yr
# Able to Scrape article24
# https://t.co/x5H1ydgEeX
# Able to Scrape article25
# https://t.co/XgI8Up76RL
# Able to Scrape article26
# https://t.co/a55VXi2XUn
# Able to Scrape article27
# https://t.co/2yszrT1Voz
# Able to Scrape article28
# https://t.co/MtgSfUs3Ze
# Able to Scrape article29
# https://t.co/PqFhbewzaE
# Able to Scrape article30
# https://t.co/aRou6Kvjv5
# Able to Scrape article31
# https://t.co/6MzrXUAIOL
# Able to Scrape article32
# https://t.co/OaqJJmGjxk
# Able to Scrape article33
# https://t.co/3TSdg3IUjy
# Able to Scrape article34
# https://t.co/N4lVky6zuJ
# Able to Scrape article35
# https://t.co/o7TU3u1hl8
# Able to Scrape article36
# https://t.co/pqENKQakQb
# Able to Scrape article37
# https://t.co/MjExekKA46
# Able to Scrape article38
# https://t.co/Ob9DgYOg8b
# Able to Scrape article39
# https://t.co/0yJjakCmJI
# Able to Scrape article40
# https://t.co/FCYmJyQ7pd
# Able to Scrape article41
# https://t.co/ZL8D78tFOY
# Able to Scrape article42
# https://t.co/LI794kwGEv
# Able to Scrape article43
# https://t.co/3U3aI3ujKt
# Able to Scrape article44
# https://t.co/b3XnYYxl0p
# Able to Scrape article45
# https://t.co/BJHwH4fQ18
# Able to Scrape article46
# https://t.co/08aYh9bAh9
# Able to Scrape article47
# https://t.co/3REHeoFdcW
# Able to Scrape article48
# https://t.co/O49hGACzHj
# Able to Scrape article49
# https://t.co/I5R24ZBUsN
# Able to Scrape article50
# https://t.co/RrxcrJvf3g
# Able to Scrape article51
# https://t.co/ClZTBnclnS
# Able to Scrape article52
# https://t.co/163exEbkxn
# Able to Scrape article53
# https://t.co/d4Wn9vz6fq
# Able to Scrape article54
# https://t.co/bt2WX0Mgpa
# Able to Scrape article55
# https://t.co/5AXhp0ZEkM
# Able to Scrape article56
# https://t.co/1YliPTFrxm
# Able to Scrape article57
# https://t.co/spm4IpO2Zr
# Able to Scrape article58
# https://t.co/iYPjUfDDa6
# Able to Scrape article59
# https://t.co/LT2mSc6iSs
# Able to Scrape article60
# https://t.co/6lB2w9Iaev
# Able to Scrape article61
# https://t.co/A9a86umREp
# Able to Scrape article62
# https://t.co/LywYhqlW5p
# Able to Scrape article63
# https://t.co/T5kq17ikfb
# Able to Scrape article64
# https://t.co/F6RZX8xcI3
# Able to Scrape article65
# https://t.co/67ZIAj306g
# Able to Scrape article66
# https://t.co/OrH0aCzcst
# Able to Scrape article67
# https://t.co/CMXs763Rsg
# Able to Scrape article68
# https://t.co/3lNFEySEKp
# Able to Scrape article69
# https://t.co/wdJ1HiD3rx
# Able to Scrape article70
# https://t.co/r8Xt5oPBAL
# Able to Scrape article71
# https://t.co/TuzjaRQOoO
# Able to Scrape article72
# https://t.co/8ChYWlPXcq
# Able to Scrape article73
# https://t.co/HTYcLKtpGa
# Able to Scrape article74
# https://t.co/gaPWZAC48E
# Able to Scrape article75
# https://t.co/1jN1O7eZgb
# Able to Scrape article76
# https://t.co/sRkmwXjqUc
# Able to Scrape article77
# https://t.co/M1Bbs375CF
# Able to Scrape article78
# https://t.co/4yJEd0pcxd
# Able to Scrape article79
# https://t.co/Ax64VFHEoC
# Able to Scrape article80
# https://t.co/uNrKjsHM4S
# Able to Scrape article81
# https://t.co/36cSwC3qD1
# Able to Scrape article82
# https://t.co/Qv8ZWPjlVc
# Able to Scrape article83
# https://t.co/YIBCt4i1Ux
# Able to Scrape article84
# https://t.co/SeNd21nEN9
# Able to Scrape article85
# https://t.co/yuEt566hFK
# Able to Scrape article86
# https://t.co/ayAdkq8Hcq
# Able to Scrape article87
# https://t.co/E12QwgHC4x
# Able to Scrape article88
# https://t.co/JU2QrWSXEp
# Able to Scrape article89
# https://t.co/gpLiokEXt1
# Able to Scrape article90
# https://t.co/DuHf0Y8Gpe
# Able to Scrape article91
# https://t.co/ta0Rvb0cQJ
# Able to Scrape article92
# https://t.co/iP5UojOlZJ
# Able to Scrape article93
# https://t.co/rwETmi2Es1
# Able to Scrape article94
# https://t.co/FkQ5rtkhqW
# Able to Scrape article95
# https://t.co/xdrjJbfUor
# Able to Scrape article96
# https://t.co/K3WOoySD0j
# Able to Scrape article97
# https://t.co/ZFWNGxsx00
# Able to Scrape article98
# https://t.co/ZHLeedxIOT
# Able to Scrape article99
# https://t.co/tsDmBFFWzi
# Able to Scrape article100
# https://t.co/RIpzQv4z8p
# Able to Scrape article101
# https://t.co/MXd4To06x5
# Able to Scrape article102
# https://t.co/VF37IVJXhL
# Able to Scrape article103
# https://t.co/EixD7R37GI
# Able to Scrape article104
# https://t.co/1HCZqbYIhF
# Able to Scrape article105
# https://t.co/2dIck4Ls8l
# Able to Scrape article106
# https://t.co/VYFkTGqGtr
# Able to Scrape article107
# https://t.co/avUoc2XNTl
# Able to Scrape article108
# https://t.co/cYZJiCA86c
# Able to Scrape article109
# https://t.co/XTRg2R4K2r
# Able to Scrape article110
# https://t.co/CL304pWUyh
# Able to Scrape article111
# https://t.co/1DTnb6m2iH
# Able to Scrape article112
# https://t.co/LlufVwXY9s
# Able to Scrape article113
# https://t.co/kIfJgUDNEc
# Able to Scrape article114
# https://t.co/QaXlYHz00g
# Able to Scrape article115
# https://t.co/iTA82eeRd3
# Able to Scrape article116
# https://t.co/a8bif6dBpC
# Able to Scrape article117
# https://t.co/55pVIRLcK8
# Able to Scrape article118
# https://t.co/0ZRVLd8LSJ
# Able to Scrape article119
# https://t.co/leOiI8uDvg
# Able to Scrape article120
# https://t.co/XwzvxyDDra
# Able to Scrape article121
# https://t.co/Y4wvSyLu30
# Able to Scrape article122
# https://t.co/DdNdGChKM0
# Able to Scrape article123
# https://t.co/0TXQ8gLDyz
# Able to Scrape article124
# https://t.co/uZ7Y3kj2xp
# Able to Scrape article125
# https://t.co/if5T7TkgjQ
# Able to Scrape article126
# https://t.co/BXNPHqFzul
# Able to Scrape article127
# https://t.co/JdZFlcX43Q
# Able to Scrape article128
# https://t.co/GQBBwgTAd3
# Able to Scrape article129
# https://t.co/IdA61UtOfM
# Able to Scrape article130
# https://t.co/FQXXtPjtaC
# Able to Scrape article131
# https://t.co/dlTFoNWCoi
# Able to Scrape article132
# https://t.co/aHkaRuTbrb
# Able to Scrape article133
# https://t.co/EeWVIRVBhk
# Able to Scrape article134
# https://t.co/Vg0nHSJgCZ
# Able to Scrape article135
# https://t.co/VsifkIQVSM
# Able to Scrape article136
# https://t.co/AvgbsfybhU
# Able to Scrape article137
# https://t.co/gAw6gpAjxH
# Able to Scrape article138
# https://t.co/EswR9P5Q9d
# Able to Scrape article139
# https://t.co/ujVshdNa1H
# Able to Scrape article140
# https://t.co/wHOL7rx0KB
# Able to Scrape article141
# https://t.co/tZpBPKlBby
# Able to Scrape article142
# https://t.co/dyjI7qdafH
# Able to Scrape article143
# https://t.co/sXjNdf64VH
# Able to Scrape article144
# https://t.co/eUYfjof59f
# Able to Scrape article145
# https://t.co/RSWz4tpCSD
# Able to Scrape article146
# https://t.co/Ljn3Xwzvdb
# Able to Scrape article147
# https://t.co/vmTY5tT6tQ
# Able to Scrape article148
# https://t.co/dxqD5pySZD
# Able to Scrape article149
# https://t.co/jy5YGbhQfE
# Able to Scrape article150
# https://t.co/KrfH5I8jzN
# Able to Scrape article151
# https://t.co/dfoInCnqRO
# Able to Scrape article152
# https://t.co/XarJY2IAJL
# Able to Scrape article153
# https://t.co/0ZvYrXM5d4
# Able to Scrape article154
# https://t.co/2GTbEK1Ih7
# Able to Scrape article155
# https://t.co/fTOypcbq1A
# Able to Scrape article156
# https://t.co/PCPjxcFF80
# Able to Scrape article157
# https://t.co/pWWz9LpPJF
# Able to Scrape article158
# https://t.co/WuyILa8qMM
# Able to Scrape article159
# https://t.co/7X7WoqvOUI
# Able to Scrape article160
#                     Datetime  retweetCount  \
# 0  2021-02-26 21:34:07+00:00            30
# 1  2021-02-24 16:59:36+00:00            21
# 2  2021-02-23 18:59:26+00:00            27
# 3  2021-02-23 18:36:55+00:00            59
# 4  2021-02-23 12:31:15+00:00            85
# 5  2021-02-23 01:37:01+00:00            77
# 6  2021-02-22 23:49:04+00:00            49
# 7  2021-02-22 07:29:13+00:00           238
# 8  2021-02-21 15:27:00+00:00           322
# 9  2021-02-19 05:44:58+00:00            28
# 10 2021-02-19 05:18:07+00:00            28
# 11 2021-02-19 00:01:05+00:00            12
# 12 2021-02-18 20:14:05+00:00            61
# 13 2021-02-18 14:29:51+00:00            39
# 14 2021-02-17 20:19:57+00:00            54
# 15 2021-02-17 18:10:34+00:00            41
# 16 2021-02-17 17:48:57+00:00            27
# 17 2021-02-16 21:51:04+00:00            83
# 18 2021-02-16 14:21:05+00:00            65
# 19 2021-02-15 06:38:55+00:00            57
# 20 2021-02-13 20:18:51+00:00            59
# 21 2021-02-13 18:05:06+00:00            25
# 22 2021-02-13 07:56:42+00:00            32
# 23 2021-02-11 21:54:06+00:00            20
# 24 2021-02-11 17:09:02+00:00            12
# 25 2021-02-11 01:26:06+00:00            22
# 26 2021-02-11 00:11:03+00:00            21
# 27 2021-02-10 11:41:36+00:00          2036
# 28 2021-02-09 08:23:29+00:00            41
# 29 2021-02-08 21:13:43+00:00            36
#
#                                                  Text        Username  \
# 0   In late September, before covid-19 swept throu...  washingtonpost
# 1   JavaScript is not available.\n\nWe’ve detected...  washingtonpost
# 2   JavaScript is not available.\n\nWe’ve detected...  washingtonpost
# 3   Comment on this story Comment Gift Article Sha...  washingtonpost
# 4   Comment on this story Comment Gift Article Sha...  washingtonpost
# 5   Comment on this story Comment Gift Article Sha...  washingtonpost
# 6   Comment on this story Comment Gift Article Sha...  washingtonpost
# 7   Warning: This graphic requires JavaScript. Ple...  washingtonpost
# 8   Warning: This graphic requires JavaScript. Ple...  washingtonpost
# 9   Comment on this story Comment Gift Article Sha...  washingtonpost
# 10  Comment on this story Comment Gift Article Sha...  washingtonpost
# 11  Comment on this story Comment Gift Article Sha...  washingtonpost
# 12  Comment on this story Comment Gift Article Sha...  washingtonpost
# 13  JavaScript is not available.\n\nWe’ve detected...  washingtonpost
# 14  Comment on this story Comment Gift Article Sha...  washingtonpost
# 15  Comment on this story Comment Gift Article Sha...  washingtonpost
# 16  Comment on this story Comment Gift Article Sha...  washingtonpost
# 17  Comment on this story Comment Gift Article Sha...  washingtonpost
# 18  I caught this virus before anyone had even die...  washingtonpost
# 19  Comment on this story Comment Gift Article Sha...  washingtonpost
# 20  Comment on this story Comment Gift Article Sha...  washingtonpost
# 21  Comment on this story Comment Gift Article Sha...  washingtonpost
# 22  Sure, “the problems of three little people don...  washingtonpost
# 23  Comment on this story Comment Gift Article Sha...  washingtonpost
# 24  Comment on this story Comment Gift Article Sha...  washingtonpost
# 25  Comment on this story Comment Gift Article Sha...  washingtonpost
# 26  Comment on this story Comment Gift Article Sha...  washingtonpost
# 27  Europe's oldest person, French nun Sister Andr...  washingtonpost
# 28  Comment on this story Comment Gift Article Sha...  washingtonpost
# 29  Rep. Ron Wright (R-Tex.), who received cancer ...  washingtonpost
#
#                                              Keywords
# 0   [town, comes, denial, quoin, face, short, du, ...
# 1   [disabled, supported, list, switch, using, jav...
# 2   [disabled, supported, list, switch, using, jav...
# 3   [covid19, visualization, toll, occurred, secon...
# 4   [lung, covid19, later, finds, donor, lungs, wo...
# 5   [pandemic, covid19, white, americans, victims,...
# 6   [lost, covid19, possible, fallen, americans, c...
# 7   [pandemic, national, war, toll, names, city, k...
# 8   [pandemic, national, war, toll, names, city, k...
# 9   [diseases, pandemic, covid19, takeaways, faile...
# 10  [testing, travelers, tests, took, test, united...
# 11  [streamline, covid19, travelers, information, ...
# 12  [say, covid19, white, test, bribed, screener, ...
# 13  [disabled, supported, list, switch, using, jav...
# 14  [cuomo, pandemic, covid19, coverup, administra...
# 15  [true, covid19, face, orientation, sexual, tol...
# 16  [negative, covid19, travelers, state, test, vi...
# 17  [need, covid19, neurology, impact, syndromes, ...
# 18  [im, ill, work, youre, start, really, told, fe...
# 19  [covid19, pills, used, treatment, livestock, s...
# 20  [covid19, pills, used, treatment, livestock, s...
# 21  [nations, fight, covid19, members, military, v...
# 22  [need, covid19, pandemic, theyre, togetherness...
# 23  [woodcock, say, bidens, drug, delay, commissio...
# 24  [pandemic, makridis, high, wu, trust, severe, ...
# 25  [enter, covid19, travelers, visitors, vaccinat...
# 26  [pandemic, covid19, bill, prevents, sick, work...
# 27  [survived, red, pandemic, flu, sister, tavella...
# 28  [stroke, child, covid19, children, tax, presid...
# 29  [covid19, rep, wright, district, statement, ba...

# %%
# users = ['ABC','CBSNews','CNN','nytimes','FoxNews','MSNBC','NBCNews','USATODAY','WSJ','washingtonpost','politico','CNET']
import re
from newspaper import Article
users = ['washingtonpost']
filters = ['Covid-19 since:2022-01-01', 'until:2022-03-31']
from_filters = []
for user in users:
    from_filters.append(f'from:{user}')
filters.append(' OR '.join(from_filters))
tweets = list(sntwitter.TwitterSearchScraper(' '.join(filters)).get_items())
print(len(tweets))
tweet_list=[]
count=1
for tweet in tweets:
    tweetContent=tweet.rawContent
    try:
        url = re.search("(?P<url>https?://[^\s]+)", tweetContent).group("url")
        print(url)
        count+=1
        try:
            toi_article = Article(url, language="en") # en for English

            #To download the article
            toi_article.download()

            #To parse the article
            toi_article.parse()

            #To perform natural language processing ie..nlp
            toi_article.nlp()

            tweet_list.append([tweet.date, tweet.retweetCount, toi_article.text, tweet.user.username, toi_article.keywords])
            print("Able to Scrape article"+str(count))
        except:
            tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
            print("Unable to Scrape article"+str(count))
    except:
        tweet_list.append([tweet.date, tweet.retweetCount, tweet.rawContent, tweet.user.username, []])
        print("Unable to Scrape article"+str(count))
df_second = pd.DataFrame(tweet_list, columns=['Datetime','retweetCount','Text', 'Username','Keywords'])
df_second.drop_duplicates(subset='Text', keep="last")
df_second.head()
# Out:
# 94
# https://t.co/MQjjWZOLlO
# Able to Scrape article2
# https://t.co/7NocmjXWn1
# Able to Scrape article3
# https://t.co/l97cMTp9Ag
# Able to Scrape article4
# https://t.co/iHTPLaJPaU
# Able to Scrape article5
# https://t.co/Iqhm8paJVu
# Able to Scrape article6
# https://t.co/x58N5vu0QG
# Able to Scrape article7
# https://t.co/lz9VIfQOcg
# Able to Scrape article8
# https://t.co/LkBtO7Ya9U
# Able to Scrape article9
# https://t.co/01o0KlxK2a
# Able to Scrape article10
# https://t.co/YkYRu2ZwBy
# Able to Scrape article11
# https://t.co/DXvoyxZASh
# Able to Scrape article12
# https://t.co/5eDlql0v9g
# Able to Scrape article13
# https://t.co/43eMG8PV8k
# Able to Scrape article14
# https://t.co/vd9CNr2mHh
# Able to Scrape article15
# https://t.co/SQRe0SjC0d
# Able to Scrape article16
# https://t.co/boovmNus4s
# Able to Scrape article17
# https://t.co/zlNQhTMnQ4
# Able to Scrape article18
# https://t.co/OaYRoiBbp5
# Able to Scrape article19
# https://t.co/YapJzstCRh
# Able to Scrape article20
# https://t.co/9rNeYyFkJg
# Able to Scrape article21
# https://t.co/GJWhFcWZjJ
# Able to Scrape article22
# https://t.co/a3oKUSYTtA
# Able to Scrape article23
# https://t.co/j3Im5r6Sqz
# Able to Scrape article24
# https://t.co/LbTwrBXtvx
# Able to Scrape article25
# https://t.co/GYTYTtCtmz
# Able to Scrape article26
# https://t.co/xF8rWWfoEQ
# Able to Scrape article27
# https://t.co/nDJc40iNiW
# Able to Scrape article28
# https://t.co/voCla2rPrW
# Able to Scrape article29
# https://t.co/oKrKpTc1Kf
# Able to Scrape article30
# https://t.co/oqfTQY0gWY
# Able to Scrape article31
# https://t.co/MEtaRPOAZm
# Able to Scrape article32
# https://t.co/prJTlbXZ5J
# Able to Scrape article33
# https://t.co/k9fFq4Gs9V
# Able to Scrape article34
# https://t.co/M3Pf4BritF
# Able to Scrape article35
# https://t.co/d4mpUPlWAz
# Able to Scrape article36
# https://t.co/GkFulCwhtq
# Able to Scrape article37
# https://t.co/NIn19ZM3rU
# Able to Scrape article38
# https://t.co/m0Dhxoy0JJ
# Able to Scrape article39
# https://t.co/1sZpMV7H9V
# Able to Scrape article40
# https://t.co/zjgmAn6nFQ
# Able to Scrape article41
# https://t.co/RJpUvRzSPn
# Able to Scrape article42
# https://t.co/x2TNpkHzhV
# Able to Scrape article43
# https://t.co/39TqRr4J0P
# Able to Scrape article44
# https://t.co/tFKp8JfaEH
# Able to Scrape article45
# https://t.co/UfzBl7lsif
# Able to Scrape article46
# https://t.co/F1ptjlFjhe
# Able to Scrape article47
# https://t.co/LoyT8MP7hn
# Able to Scrape article48
# https://t.co/CUGfze0FGO
# Able to Scrape article49
# https://t.co/KmewJME3OF
# Able to Scrape article50
# https://t.co/CT9DXh9NM5
# Able to Scrape article51
# https://t.co/KPpWvu07Kf
# Able to Scrape article52
# https://t.co/jMBsBeM3Rz
# Able to Scrape article53
# https://t.co/xDxrqVTgSV
# Able to Scrape article54
# https://t.co/RzDqhRKT5N
# Able to Scrape article55
# https://t.co/e1xvbbgx3O
# Able to Scrape article56
# https://t.co/OzomJdPZMS
# Able to Scrape article57
# https://t.co/CJdn53WbDI
# Able to Scrape article58
# https://t.co/o1bCYAKk4M
# Able to Scrape article59
# https://t.co/5EriYJt96H
# Able to Scrape article60
# https://t.co/e7U0QxhqIT
# Able to Scrape article61
# https://t.co/gsftN1Huyb
# Able to Scrape article62
# https://t.co/C7zPO7khy1
# Able to Scrape article63
# https://t.co/FoEIVreeTI
# Able to Scrape article64
# https://t.co/mn2M49CAUv
# Able to Scrape article65
# https://t.co/nIiRu4Sokr
# Able to Scrape article66
# https://t.co/cIxnXFDh39
# Able to Scrape article67
# https://t.co/GmH3Y0uj1A
# Able to Scrape article68
# https://t.co/VA2xeZGqwh
# Able to Scrape article69
# https://t.co/UbiA6gM1sq
# Able to Scrape article70
# https://t.co/nZIM0O0A6L
# Able to Scrape article71
# https://t.co/xNM7bLLmJ5
# Able to Scrape article72
# https://t.co/4nYQrNaGss
# Able to Scrape article73
# https://t.co/dCsnV6egac
# Able to Scrape article74
# https://t.co/cYTbN65EXI
# Able to Scrape article75
# https://t.co/qaVa89XkTx
# Able to Scrape article76
# https://t.co/LtN8wgCpDL
# Able to Scrape article77
# https://t.co/etGFNwSEzl
# Able to Scrape article78
# https://t.co/PGNJdrxzSo
# Able to Scrape article79
# https://t.co/YM5DFJ8IB1
# Able to Scrape article80
# https://t.co/Rf4hgQwoqW
# Able to Scrape article81
# https://t.co/7r7Ain1cfD
# Able to Scrape article82
# https://t.co/zExF3mNFJT
# Able to Scrape article83
# https://t.co/j4SiVO9vFU
# Able to Scrape article84
# https://t.co/xGJqSo2cGL
# Able to Scrape article85
# https://t.co/gRRO0i0mR1
# Able to Scrape article86
# https://t.co/ZhQMzecY8M
# Able to Scrape article87
# https://t.co/pBMCc9OuKr
# Able to Scrape article88
# https://t.co/q7MKINuAcc
# Able to Scrape article89
# https://t.co/uOJxk7VsQ8
# Able to Scrape article90
# https://t.co/4zNXMMDgj1
# Able to Scrape article91
# https://t.co/eS7VL3hLxL
# Able to Scrape article92
# https://t.co/CaUnwsMC1v
# Able to Scrape article93
# https://t.co/uPrL0OziUn
# Able to Scrape article94
# https://t.co/14bi7Zk9FY
# Able to Scrape article95
#                    Datetime  retweetCount  \
# 0 2022-03-29 00:36:03+00:00            55
# 1 2022-03-28 14:50:24+00:00            71
# 2 2022-03-22 12:00:26+00:00            64
# 3 2022-03-22 00:39:31+00:00            81
# 4 2022-03-18 19:24:09+00:00            63
#
#                                                 Text        Username  \
# 0  Listen 11 min Comment on this story Comment Gi...  washingtonpost
# 1  Listen 6 min Comment on this story Comment Gif...  washingtonpost
# 2  Listen 3 min Comment on this story Comment Gif...  washingtonpost
# 3  Listen 3 min Comment on this story Comment Gif...  washingtonpost
# 4  Local The unequal toll of the omicron wave In ...  washingtonpost
#
#                                             Keywords
# 0  [money, brace, medical, federal, coronavirus, ...
# 1  [chinese, policy, measures, surges, china, inf...
# 2  [covid19, records, million, va, coronavirus, r...
# 3  [covid19, records, million, va, coronavirus, r...
# 4  [covid19, unequal, toll, wave, vaccinated, omi...

# %%
df_final=pd.concat([df_first, df_second], ignore_index=True)
df_final.head(30)
# Out:
#                     Datetime  retweetCount  \
# 0  2021-02-26 21:34:07+00:00            30
# 1  2021-02-24 16:59:36+00:00            21
# 2  2021-02-23 18:59:26+00:00            27
# 3  2021-02-23 18:36:55+00:00            59
# 4  2021-02-23 12:31:15+00:00            85
# 5  2021-02-23 01:37:01+00:00            77
# 6  2021-02-22 23:49:04+00:00            49
# 7  2021-02-22 07:29:13+00:00           238
# 8  2021-02-21 15:27:00+00:00           322
# 9  2021-02-19 05:44:58+00:00            28
# 10 2021-02-19 05:18:07+00:00            28
# 11 2021-02-19 00:01:05+00:00            12
# 12 2021-02-18 20:14:05+00:00            61
# 13 2021-02-18 14:29:51+00:00            39
# 14 2021-02-17 20:19:57+00:00            54
# 15 2021-02-17 18:10:34+00:00            41
# 16 2021-02-17 17:48:57+00:00            27
# 17 2021-02-16 21:51:04+00:00            83
# 18 2021-02-16 14:21:05+00:00            65
# 19 2021-02-15 06:38:55+00:00            57
# 20 2021-02-13 20:18:51+00:00            59
# 21 2021-02-13 18:05:06+00:00            25
# 22 2021-02-13 07:56:42+00:00            32
# 23 2021-02-11 21:54:06+00:00            20
# 24 2021-02-11 17:09:02+00:00            12
# 25 2021-02-11 01:26:06+00:00            22
# 26 2021-02-11 00:11:03+00:00            21
# 27 2021-02-10 11:41:36+00:00          2036
# 28 2021-02-09 08:23:29+00:00            41
# 29 2021-02-08 21:13:43+00:00            36
#
#                                                  Text        Username  \
# 0   In late September, before covid-19 swept throu...  washingtonpost
# 1   JavaScript is not available.\n\nWe’ve detected...  washingtonpost
# 2   JavaScript is not available.\n\nWe’ve detected...  washingtonpost
# 3   Comment on this story Comment Gift Article Sha...  washingtonpost
# 4   Comment on this story Comment Gift Article Sha...  washingtonpost
# 5   Comment on this story Comment Gift Article Sha...  washingtonpost
# 6   Comment on this story Comment Gift Article Sha...  washingtonpost
# 7   Warning: This graphic requires JavaScript. Ple...  washingtonpost
# 8   Warning: This graphic requires JavaScript. Ple...  washingtonpost
# 9   Comment on this story Comment Gift Article Sha...  washingtonpost
# 10  Comment on this story Comment Gift Article Sha...  washingtonpost
# 11  Comment on this story Comment Gift Article Sha...  washingtonpost
# 12  Comment on this story Comment Gift Article Sha...  washingtonpost
# 13  JavaScript is not available.\n\nWe’ve detected...  washingtonpost
# 14  Comment on this story Comment Gift Article Sha...  washingtonpost
# 15  Comment on this story Comment Gift Article Sha...  washingtonpost
# 16  Comment on this story Comment Gift Article Sha...  washingtonpost
# 17  Comment on this story Comment Gift Article Sha...  washingtonpost
# 18  I caught this virus before anyone had even die...  washingtonpost
# 19  Comment on this story Comment Gift Article Sha...  washingtonpost
# 20  Comment on this story Comment Gift Article Sha...  washingtonpost
# 21  Comment on this story Comment Gift Article Sha...  washingtonpost
# 22  Sure, “the problems of three little people don...  washingtonpost
# 23  Comment on this story Comment Gift Article Sha...  washingtonpost
# 24  Comment on this story Comment Gift Article Sha...  washingtonpost
# 25  Comment on this story Comment Gift Article Sha...  washingtonpost
# 26  Comment on this story Comment Gift Article Sha...  washingtonpost
# 27  Europe's oldest person, French nun Sister Andr...  washingtonpost
# 28  Comment on this story Comment Gift Article Sha...  washingtonpost
# 29  Rep. Ron Wright (R-Tex.), who received cancer ...  washingtonpost
#
#                                              Keywords
# 0   [town, comes, denial, quoin, face, short, du, ...
# 1   [disabled, supported, list, switch, using, jav...
# 2   [disabled, supported, list, switch, using, jav...
# 3   [covid19, visualization, toll, occurred, secon...
# 4   [lung, covid19, later, finds, donor, lungs, wo...
# 5   [pandemic, covid19, white, americans, victims,...
# 6   [lost, covid19, possible, fallen, americans, c...
# 7   [pandemic, national, war, toll, names, city, k...
# 8   [pandemic, national, war, toll, names, city, k...
# 9   [diseases, pandemic, covid19, takeaways, faile...
# 10  [testing, travelers, tests, took, test, united...
# 11  [streamline, covid19, travelers, information, ...
# 12  [say, covid19, white, test, bribed, screener, ...
# 13  [disabled, supported, list, switch, using, jav...
# 14  [cuomo, pandemic, covid19, coverup, administra...
# 15  [true, covid19, face, orientation, sexual, tol...
# 16  [negative, covid19, travelers, state, test, vi...
# 17  [need, covid19, neurology, impact, syndromes, ...
# 18  [im, ill, work, youre, start, really, told, fe...
# 19  [covid19, pills, used, treatment, livestock, s...
# 20  [covid19, pills, used, treatment, livestock, s...
# 21  [nations, fight, covid19, members, military, v...
# 22  [need, covid19, pandemic, theyre, togetherness...
# 23  [woodcock, say, bidens, drug, delay, commissio...
# 24  [pandemic, makridis, high, wu, trust, severe, ...
# 25  [enter, covid19, travelers, visitors, vaccinat...
# 26  [pandemic, covid19, bill, prevents, sick, work...
# 27  [survived, red, pandemic, flu, sister, tavella...
# 28  [stroke, child, covid19, children, tax, presid...
# 29  [covid19, rep, wright, district, statement, ba...

# %%
df_final['truthfulness']='0'

# %%
df_final.to_csv('washingtonpost.csv', encoding='utf-8', index=False)
