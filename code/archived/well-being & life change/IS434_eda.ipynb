# %% [markdown]
# **Importing the data**

# %%
# from google.colab import drive
# from google.colab import files
# drive.mount('/content/drive')

# %%
import pandas as pd
import re
import nltk

# %%
dataset_dir = 'output/'

# %%
# df1 = pd.read_csv(dataset_dir + 'Bryson_DeChambeau(Jul2019-Feb2023).csv')
# df2 = pd.read_csv(dataset_dir + 'JonathanIsaac(Jul2019-Feb2023).csv')
# df3 = pd.read_csv(dataset_dir + 'Kyrie_Irving(Jul2019-Feb2023).csv')
# df4 = pd.read_csv(dataset_dir + 'Tom_Dean(Jul2019-Feb2023).csv')
# df5 = pd.read_csv(dataset_dir + 'djokovic(Jul2019-Feb2023).csv')
# df6 = pd.read_csv(dataset_dir + 'Simone_Biles(Jul2019-Feb2023).csv')
df = pd.read_csv(dataset_dir + 'combinetweets.csv')

# %%
# frames = [df1, df2, df3, df4, df5, df6]

# result = pd.concat(frames)

# %%
df
# Out:
#       Unnamed: 0                  date_time             tweet_id  \
# 0              0  2023-02-27 15:00:25+00:00  1630221319362031616
# 1              1  2023-02-25 14:13:10+00:00  1629484655475937283
# 2              2  2023-02-25 14:12:16+00:00  1629484429272924161
# 3              3  2023-01-30 13:10:33+00:00  1620046812311871492
# 4              4  2023-01-29 14:40:49+00:00  1619707140306001920
# ...          ...                        ...                  ...
# 2209         339  2019-07-10 18:24:10+00:00  1149021510230859776
# 2210         340  2019-07-09 13:37:04+00:00  1148586873016717312
# 2211         341  2019-07-09 02:05:35+00:00  1148412855772962816
# 2212         342  2019-07-07 23:17:48+00:00  1148008242410328064
# 2213         343  2019-07-06 01:38:04+00:00  1147318766352687109
#
#                                                     url userlocation  \
# 0     https://twitter.com/DjokerNole/status/16302213...          NaN
# ...

# %%
import re
import numpy as np

# %%
#https://catriscode.com/2021/05/01/tweets-cleaning-with-python/


def clean_tweet(tweet):
    stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    # temp = re.sub("'", "", temp) # to avoid removing contractions in english
    # temp = re.sub("@[A-Za-z0-9_]+","", temp)
    # temp = re.sub("#[A-Za-z0-9_]+","", temp)
    #removing links
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    #removing punctuations
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    #removing nonalphanumeric char
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp


tweets = df["text"]
cleaned_tweets = [clean_tweet(tw) for tw in tweets]
cleaned_tweets
# Out:
# C:\Users\hannah.kim\AppData\Local\Temp\ipykernel_32232\4089323353.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['378 blessed grateful',
#  '',
#  'good be back dubai ddftennis let s go team dubajkovi',
#  'novakfoundation',
#  '2 2',
#  'semis idemooo ausopen manan vatsyayana',
#  '',
#  '',
#  'such amazing welcome thank you',
#  'adelaideinternational',
#  '',
#  'finals idemooo adelaideinternational sarah reed adelaide international',
#  'tennistv',
# ...

# %%
df["cleaned_tweets"]=cleaned_tweets
df
# Out:
#       Unnamed: 0                  date_time             tweet_id  \
# 0              0  2023-02-27 15:00:25+00:00  1630221319362031616
# 1              1  2023-02-25 14:13:10+00:00  1629484655475937283
# 2              2  2023-02-25 14:12:16+00:00  1629484429272924161
# 3              3  2023-01-30 13:10:33+00:00  1620046812311871492
# 4              4  2023-01-29 14:40:49+00:00  1619707140306001920
# ...          ...                        ...                  ...
# 2209         339  2019-07-10 18:24:10+00:00  1149021510230859776
# 2210         340  2019-07-09 13:37:04+00:00  1148586873016717312
# 2211         341  2019-07-09 02:05:35+00:00  1148412855772962816
# 2212         342  2019-07-07 23:17:48+00:00  1148008242410328064
# 2213         343  2019-07-06 01:38:04+00:00  1147318766352687109
#
#                                                     url userlocation  \
# 0     https://twitter.com/DjokerNole/status/16302213...          NaN
# ...

# %%
df.to_csv('combinedtweets+preprocessedt.csv')
# files.download('output.csv')

# %%
covid_name_list = ["covid","sars-cov-2","pandemic","lockdown","lock down", "" ]
covid =df[df["cleaned_tweets"].str.contains("mask")]
covid
# Out:
#       Unnamed: 0                  date_time             tweet_id  \
# 1604         248  2021-09-15 23:45:21+00:00  1438287856703737857
# 1605         249  2021-09-15 15:21:06+00:00  1438160955192459278
#
#                                                     url userlocation  \
# 1604  https://twitter.com/KyrieIrving/status/1438287...       YAHWEH
# 1605  https://twitter.com/KyrieIrving/status/1438160...       YAHWEH
#
#       like_count  retweet_count  \
# 1604       30282           4421
# 1605       29191           4167
#
#                                                    text     username  \
# 1604  “Mask off” means\nYou stop being something you...  KyrieIrving
# 1605       My mask is off. Now take yours off. No fear.  KyrieIrving
#
#       follower_count  reply_count hashtags  \
# 1604         4812579         1152      NaN
# 1605         4812579         2053      NaN
#
#                                          cleaned_tweets
# ...

# %%
#use amazon reokcognition
