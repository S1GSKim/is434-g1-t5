# %%
import nltk

# nltk.download('stopwords')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# %%
# Gensim (Topic Modeling Pacakge)
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
# spacy for lemmatization
import spacy

from spacy_download import load_spacy

# %%
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
'''
We will be using the 20-Newsgroups dataset for this exercise.
This version of the dataset contains about 11k newsgroups posts from 
20 different topics. This is available as newsgroups.json.
'''
# Import Dataset
df = pd.read_csv('data/during2_covidTweets_v2.csv')
print(df.username.unique())
df.head()
df.count()
# Out:
# ['TheWadSquad_io' 'sharonlafon91' 'JDignum' 'Zolgath1' 'thestug1985'
#  'kittenhawk1' 'BiotechObserver' 'Ride4Truth' 'COVID19STATS3'
#  'Michael91693258' 'mileslunn' 'newsnow_africa' 'Americanhope78'
#  'Sharky_vs_Evil' 'OppenheimAviel' 'TorontoStar' 'DonEford' 'MJMcElwee'
#  'JenniferMeyer6' 'michaelab97' 'car_trump' 'NzuchiTimesUSA'
#  'ZyiteGadgets' 'GlobalCirculate' 'thepostxnews' 'theesk' 'RioSlade'
#  'JoyLing6' 'Truth_in_Number' 'LazarusLong13' 'PELCltd' 'healthylivingHe'
#  'KathMLee1' 'DrWaldoAyurveda' 'healthfoodat' 'jondknight'
#  'sheilab06007273' 'McKibbinGroup' 'chelseakenna' 'troothmonstah'
#  'USAfireman01' 'STForeignDesk' 'pastexpiry' 'GosiaGasperoPhD' 'Njayije'
#  'Bricky1WI' 'TrueDiagnostics' 'bettycjung' 'SerenaShimAward'
#  'Heather65557169' '1Alboforpm' 'StCatStandard' 'njoyflyfishing'
#  'Savage707Savage' 'gtamoeb' '_covid_19_bot_' 'adihridreamland'
#  'MonicaGandhi9' 'calexander007' 'ZakGregg' 'this1wierdgirl' 'juli_bg_bs'
#  'jruban15' 'woodrowdouglass' 'aparachick' 'CoeurdelaMer37'
#  '_cryptomatters' 'stillwemadeit' 'JoeBlog05100722' 'isearch247' 'DR_ILL'
#  'jccnc16' '1Artypod' 'ColmanOfGuaire' 'pogue25' 'FluoridePoison'
#  'DiasporaEngager' 'DiasporaNews123' 'LarsonFanChris' 'jowens8614'
#  'healthystartgo' 'EGliasain' 'KKorncob' 'TheDriveInn1' 'smdemora'
#  'Phage_Papers' 'KevintheVille' 'NoNegativeWave1' 'jeguru1' 'nspector4'
#  'jkstudentupdate' 'bot_political' 'littlebytesnews' 'somershade1'
#  'kolby_anthony' 'The_King_SteveO' 'CarterKvbbiz' 'gemcarey' 'DeetoriaDee'
#  'SamLace65948404' 'EarlGreyTea_pls' 'deadlystingnyc' 'jaunnewsusa'
#  'WellandTribune' 'RF_Jenkins' 'IgorZepol' 'AGB07003591' 'jirkyrick'
#  'DeepADiver2' 'LostTogetherCda' 'CastelinoJenny' 'godlovesgoths'
#  'tearoeprice' 'VanessaQT' '_shnieder' 'HamidMerchant' 'suchipi'
#  'TelecasterRon' 'Richie07849741' 'meshaiman' 'JoshAlexCairo' 'WMUR9'
#  'LussianaK' 'sarahplusone' 'SocialPolicyAUS' 'eurojournalENG'
#  'Epiwhisper' 'TodayHeadline42' 'Cadoret' 'ElephantNewsUSA' 'StaciaLevy'
#  'Totallysamsays' 'LadyOphelia9' 'maximus_hoggus' 'casscassptyltd'
#  'BanglaViral' 'bacchaus351' 'mareefeb' 'ItsKnivesOnly' 'thatcuteDog'
#  'Reuters' 'typo_cat' 'bitco_united' 'UtsuroBune66' 'catladyactivist'
#  'lucilovesmic' 'yfc2016' 'BregmanPs' 'healthnewsmore' 'ConcernedofBri1'
#  'TheJamieGlick' 'COVID19LiveNow' 'brimetimenole' 'cmencke' 'joelsalmon01'
#  'PhyllisBaker89' 'PurpRmPolitics' 'marclappin' 'HilaryWollis'
#  'JudithAPadilla1' 'GroupZirigoza' 'tmillerphotos' '_Yggdrassil'
#  'jdavidson2017' 'intohoIIand' 'Lucy17269389' 'MrsMommaAce' 'Wxgirl169'
#  'HITManZac' '543coolio' 'sg325is' 'agargmd' 'ShutUpChewy' 'GBAFReview'
#  'GradyTripp00' 'allendh' 'TomthunkitsMind' 'Adam_Stirling' 'leannemo1'
#  'WPalmerCurl' 'worldnews_guru' '55leeanne' 'Lionnesss' 'curategg'
#  'adonitacara' 'dianaberrent' 'openletterbot' 'AmazonAllie73'
#  'JBrady70373767' 'MojackMarine' 'r_brownlee' 'OCcovidkids' 'MoriartyLab'
#  'DrAnnInStPaul' 'AmityLassiter' 'MrDLPFC' 'LimestoneDSB']
# datetime          86093
# tweet_id          86093
# text              86093
# username          86093
# url               86093
# user_location     63516
# like_count        86093
# retweet_count     86093
# follower_count    86093
# reply_count       86093
# verified          86093
# hashtags          10863
# dtype: int64

# %%
'''
As you can see there are many emails, newline and extra spaces that is quite distracting.
Let’s get rid of them using regular expressions.
'''
# Convert to list
data = df.text.tolist()

# Remove Emails
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]

#remove URL
data = [re.sub('http://\S+|https://\S+', '', sent) for sent in data]
data = [re.sub('http[s]?://\S+', '', sent) for sent in data]
data = [re.sub(r"http\S+", "", sent) for sent in data]

# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

pprint(data[:1])
# Out:
# ['5stars #sputnik']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['stars', 'sputnik']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['stars_sputnik']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Will download the model if it isn't installed yet 
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])



print(data_lemmatized[:1])
# Out:
# [['stars_sputnik']]

# %%
import gensim.corpora as corpora

# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1)]]

# %%
vocab = len(id2word.token2id)

pd.Series([t for tokens in data_words_bigrams for t in tokens if "_" in t]).unique()
# Out:
# array(['stars_sputnik', 'sars_cov', 'spike_proteins', ...,
#        'yesterdays_summary', 'roundup_top', 'oc_districts'], dtype=object)

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.152*"people" + 0.050*"die" + 0.030*"well" + 0.026*"help" + 0.025*"risk" + '
#   '0.025*"health" + 0.023*"come" + 0.020*"pandemic" + 0.020*"age" + '
#   '0.018*"save"'),
#  (1,
#   '0.162*"report" + 0.034*"city" + 0.028*"want" + 0.027*"month" + '
#   '0.027*"cause" + 0.027*"booster" + 0.024*"update" + 0.024*"daily" + '
#   '0.019*"change" + 0.019*"term"'),
#  (2,
#   '0.067*"number" + 0.043*"official" + 0.029*"early" + 0.026*"vaccinate" + '
#   '0.023*"mild" + 0.021*"read" + 0.020*"hospitalization" + 0.018*"population" '
#   '+ 0.016*"restriction" + 0.015*"leave"'),
#  (3,
#   '0.220*"active" + 0.213*"source" + 0.023*"say" + 0.019*"high" + '
#   '0.018*"still" + 0.017*"think" + 0.015*"expect" + 0.015*"s" + 0.014*"week" + '
#   '0.013*"person"'),
#  (4,
#   '0.099*"province" + 0.092*"look" + 0.087*"way" + 0.054*"vaccinated" + '
#   '0.039*"period" + 0.036*"actual" + 0.035*"assume" + 0.033*"fact" + '
#   '0.032*"treat" + 0.020*"fully"'),
#  (5,
#   '0.326*"case" + 0.160*"count" + 0.157*"total" + 0.061*"death" + 0.037*"usd" '
#   '+ 0.021*"sd" + 0.019*"capistrano_usd" + 0.018*"anaheim_elementary" + '
#   '0.015*"go" + 0.013*"rate"'),
#  (6,
#   '0.049*"know" + 0.040*"need" + 0.037*"many" + 0.034*"test" + 0.028*"due" + '
#   '0.026*"likely" + 0.026*"wave" + 0.020*"datum" + 0.019*"vax" + '
#   '0.017*"mandate"'),
#  (7,
#   '0.129*"see" + 0.058*"tell" + 0.049*"infect" + 0.032*"low" + 0.031*"family" '
#   '+ 0.031*"life" + 0.030*"omicron" + 0.029*"always" + 0.025*"immunity" + '
#   '0.022*"surrender"'),
#  (8,
#   '0.377*"covid" + 0.048*"get" + 0.024*"infection" + 0.021*"long" + '
#   '0.015*"mask" + 0.014*"protection" + 0.013*"time" + 0.013*"school" + '
#   '0.013*"district" + 0.012*"give"'),
#  (9,
#   '0.137*"vaccine" + 0.043*"site" + 0.032*"day" + 0.026*"work" + 0.025*"right" '
#   '+ 0.023*"happen" + 0.022*"base" + 0.019*"lot" + 0.019*"testing" + '
#   '0.017*"variant"')]

# %%
'''
Model perplexity and topic coherence provide a convenient measure to judge 
how good a given topic model is. In my experience, topic coherence score, 
in particular, has been more helpful.
'''
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -8.352223646073977
#
# Coherence Score:  0.333902792371882

# %%
'''
Now that the LDA model is built, the next step is to examine the produced 
topics and the associated keywords. There is no better tool than pyLDAvis package’s 
interactive chart and is designed to work well with jupyter notebooks.
'''
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# C:\Users\hannah.kim\AppData\Roaming\Python\Python39\site-packages\pyLDAvis\_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 8     -0.164343 -0.398577       1        1  23.668872
# 3     -0.152833 -0.039972       2        1  15.093665
# 5     -0.348319  0.253588       3        1  12.527277
# 6      0.033930  0.025144       4        1  11.002323
# 0      0.073201  0.045094       5        1   9.360387
# 9      0.060986  0.041065       6        1   9.318605
# 2      0.096322 -0.016353       7        1   6.930322
# 1      0.099312  0.037255       8        1   6.465071
# 7      0.146025  0.029018       9        1   4.138081
# 4      0.155719  0.023739      10        1   1.495397, topic_info=                   Term          Freq         Total Category  logprob  loglift
# 1                 covid  80637.000000  80637.000000  Default  30.0000  30.0000
# 4                  case  36980.000000  36980.000000  Default  29.0000  29.0000
# 2219             active  29977.000000  29977.000000  Default  28.0000  28.0000
# 98               source  29095.000000  29095.000000  Default  27.0000  27.0000
# 266               count  18166.000000  18166.000000  Default  26.0000  26.0000
# ...                 ...           ...           ...      ...      ...      ...
# 604                type    120.430119    121.405249  Topic10  -4.7209   4.1947
# 1436            helpful    115.511303    116.486981  Topic10  -4.7626   4.1944
# 203              answer    114.554057    115.529125  Topic10  -4.7709   4.1943
# 21100        claim_type     90.923714     91.904850  Topic10  -5.0020   4.1920
# 21101  comusav_movement     90.923714     91.904850  Topic10  -5.0020   4.1920
#
# [337 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 286       8  0.998091      able
# 2219      2  0.999960    active
# 47       10  0.997822    actual
# 90        2  0.998866  actually
# 175       5  0.999725       age
# ...     ...       ...       ...
# 468       6  0.999346      work
# 38        3  0.998087     world
# 1649      8  0.999289     write
# 89        2  0.999271      year
# 373       8  0.999093       yet
#
# [329 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[9, 4, 6, 7, 1, 10, 3, 2, 8, 5])

# %%
output = lda_model.show_topics(num_words=30)

# %%
output_df = pd.DataFrame()
for o in output:    
    d = {}
    topic_num = o[0]
    distribution = o[1]
    decimal_list = re.findall(r'\d+\.\d+', distribution)
    word_list = re.findall(r'"([^"]*)"', distribution)
    d["topic_" + str(topic_num + 1) + "_word"] = word_list
    d["topic_" + str(topic_num + 1) + "_dist"] =  decimal_list

    topic_df = pd.DataFrame(d)
    output_df = pd.concat([output_df, topic_df], axis=1)

output_df
# Out:
#     topic_1_word topic_1_dist   topic_2_word topic_2_dist     topic_3_word  \
# 0         people        0.152         report        0.162           number
# 1            die        0.050           city        0.034         official
# 2           well        0.030           want        0.028            early
# 3           help        0.026          month        0.027        vaccinate
# 4           risk        0.025          cause        0.027             mild
# 5         health        0.025        booster        0.027             read
# 6           come        0.023         update        0.024  hospitalization
# 7       pandemic        0.020          daily        0.024       population
# 8            age        0.020         change        0.019      restriction
# 9           save        0.018           term        0.019            leave
# 10       country        0.017            yet        0.017           damage
# 11           use        0.017          least        0.017         probably
# 12         avoid        0.013  icu_admission        0.016             rise
# 13          play        0.013          write        0.015             true
# 14    government        0.012            hit        0.013          moderna
# 15          less        0.012           lose        0.012            surge
# 16          soon        0.011             qc        0.012          average
# 17           old        0.011           real        0.012         previous
# 18          kill        0.011           feel        0.011             part
# 19        reduce        0.010         second        0.011           doctor
# 20       include        0.010      available        0.011            break
# 21         clear        0.010          learn        0.010              few
# 22       disease        0.009           slow        0.010      hospitalize
# 23        severe        0.009         effect        0.010        effective
# 24           put        0.008        politic        0.009    sign_increase
# 25         quite        0.008           able        0.009             team
# 26           run        0.007          maybe        0.009         contract
# 27         alone        0.006        measure        0.009     deliver_copy
# 28  unvaccinated        0.006           cost        0.009         negative
# 29       outcome        0.006           gift        0.008             rule
#
#    topic_3_dist topic_4_word topic_4_dist        topic_5_word topic_5_dist  \
# 0         0.067       active        0.220            province        0.099
# 1         0.043       source        0.213                look        0.092
# 2         0.029          say        0.023                 way        0.087
# 3         0.026         high        0.019          vaccinated        0.054
# 4         0.023        still        0.018              period        0.039
# 5         0.021        think        0.017              actual        0.036
# 6         0.020       expect        0.015              assume        0.035
# 7         0.018            s        0.015                fact        0.033
# 8         0.016         week        0.014               treat        0.032
# 9         0.015       person        0.013               fully        0.020
# 10        0.013         year        0.012               bring        0.019
# 11        0.013         take        0.012                 bed        0.017
# 12        0.012            m        0.012                half        0.015
# 13        0.012        today        0.011             similar        0.014
# 14        0.011         even        0.010               purge        0.012
# 15        0.010        first        0.010                fail        0.011
# 16        0.010     hospital        0.010               basic        0.010
# 17        0.010         good        0.009           joe_biden        0.010
# 18        0.010         care        0.009        exposed_gold        0.010
# 19        0.009         much        0.009        star_familie        0.010
# 20        0.009      prevent        0.008      secret_service        0.010
# 21        0.008         live        0.008     trump_knowingly        0.010
# 22        0.008          try        0.008        evening_week        0.009
# 23        0.008         hear        0.007  controversial_drug        0.009
# 24        0.008     actually        0.007          whose_wife        0.009
# 25        0.008         find        0.006                type        0.009
# 26        0.008         sure        0.005             helpful        0.009
# 27        0.008       spread        0.005              answer        0.008
# 28        0.008        other        0.005    comusav_movement        0.007
# 29        0.007         safe        0.005        toxic_bleach        0.007
#
#             topic_6_word topic_6_dist topic_7_word topic_7_dist  topic_8_word  \
# 0                   case        0.326         know        0.049           see
# 1                  count        0.160         need        0.040          tell
# 2                  total        0.157         many        0.037        infect
# 3                  death        0.061         test        0.034           low
# 4                    usd        0.037          due        0.028        family
# 5                     sd        0.021       likely        0.026          life
# 6         capistrano_usd        0.019         wave        0.026       omicron
# 7     anaheim_elementary        0.018        datum        0.020        always
# 8                     go        0.015          vax        0.019      immunity
# 9                   rate        0.013      mandate        0.017     surrender
# 10                   new        0.012       pfizer        0.016          fast
# 11                  dose        0.011         show        0.016       provide
# 12             mortality        0.008       excess        0.015        return
# 13       placentia_yorba        0.008      believe        0.014          link
# 14       fullerton_joint        0.006           rd        0.013          plan
# 15            orange_usd        0.006        union        0.013          wane
# 16  fullerton_elementary        0.005         mean        0.012        thread
# 17        westminster_sd        0.005      current        0.012          rest
# 18            multi_site        0.005        never        0.011     literally
# 19            ocean_view        0.005      support        0.011       tonight
# 20        cypress_school        0.004      symptom        0.010     overwhelm
# 21               protect        0.004     increase        0.010  asymptomatic
# 22       magnolia_school        0.004     positive        0.010        travel
# 23                  next        0.003        point        0.010       decline
# 24           information        0.003      patient        0.010        remain
# 25               receive        0.003       region        0.009        entire
# 26                 world        0.003    reporting        0.009       imagine
# 27                    do        0.003       follow        0.009          love
# 28                 share        0.002      already        0.009         drive
# 29                friend        0.002     question        0.009          drug
#
#    topic_8_dist topic_9_word topic_9_dist topic_10_word topic_10_dist
# 0         0.129        covid        0.377       vaccine         0.137
# 1         0.058          get        0.048          site         0.043
# 2         0.049    infection        0.024           day         0.032
# 3         0.032         long        0.021          work         0.026
# 4         0.031         mask        0.015         right         0.025
# 5         0.031   protection        0.014        happen         0.023
# 6         0.030         time        0.013          base         0.022
# 7         0.029       school        0.013           lot         0.019
# 8         0.025     district        0.013       testing         0.019
# 9         0.022         give        0.012       variant         0.017
# 10        0.021         also        0.012          post         0.016
# 11        0.021     estimate        0.012        future         0.015
# 12        0.017        staff        0.011          lead         0.015
# 13        0.017         make        0.010            ve         0.015
# 14        0.014        thing        0.009         issue         0.012
# 15        0.013    treatment        0.008           far         0.011
# 16        0.013        child        0.008         watch         0.011
# 17        0.013          kid        0.008           big         0.011
# 18        0.010           re        0.008        enough         0.010
# 19        0.009       really        0.007          talk         0.010
# 20        0.009          end        0.007     different         0.010
# 21        0.009         keep        0.007      possible         0.009
# 22        0.009          amp        0.007          free         0.009
# 23        0.008  vaccination        0.007         group         0.009
# 24        0.008         last        0.006        listen         0.009
# 25        0.008  coronavirus        0.006        reason         0.008
# 26        0.008         fund        0.006          call         0.008
# 27        0.008         back        0.006       problem         0.008
# 28        0.008          bad        0.006     dashboard         0.007
# 29        0.007     canadian        0.006           lie         0.007
