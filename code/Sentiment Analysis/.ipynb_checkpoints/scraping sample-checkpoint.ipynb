# %%
#https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8437406/
#https://blog.twitter.com/en_us/topics/company/2020/covid19-vaccine

# %%
#pip install twarc
#!pip install boto3

# %%
# !pip install snscrape

# %%
import json
import csv
import requests
import sys
import os
import pandas as pd
# from smart_open import smart_open
# import datetime
# import time
import random
import boto3
import numpy as np
# from io import StringIO
import io
from twarc import Twarc

# %%
#AWS keys
os.environ['AWS_ACCESS_KEY_ID'] = 'AKIAW7ZYEJ4SZK7AKXEG'
os.environ['AWS_SECRET_ACCESS_KEY'] = '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'

#print(os.environ)

#Tweeter keys
consumer_key="WhPagaMZBUuTq4NdNqrDgdFXy"
consumer_secret="1EqZ2df3HvvcSy2oCvcZbSCmt328hE0VFbvCd26afOQkAGLH4G"
access_token="713239159306002432-Wo49OOI3jpAEti71yl3hb6oTAiFaxGL"
access_token_secret="pFyVrhxyHsDdgYfWr9HYecfEbrrOTKleTuuCqWJYiNQRw"

# %%
s3_client = boto3.client('s3',
                  aws_access_key_id = os.environ['AWS_ACCESS_KEY_ID'],
                  aws_secret_access_key = os.environ['AWS_SECRET_ACCESS_KEY'])

# %%
bucket = "is434-g1t5"

during1_path = "unhydrated-data/during-covid-1/"
# corona_tweets_258.csv - corona_tweets_346.csv
during2_path = "unhydrated-data/during-covid-2/"
# corona_tweets_654.csv - corona_tweets_742.csv
post_path = "unhydrated-data/post-covid/"
# corona_tweets_988.csv - corona_tweets_1077.csv

all_df_during1=[]
all_df_during2=[]
all_df_post=[]

# for i in range(258,347):
for i in range(258,260):
    print(i)
    obj = s3_client.get_object(Bucket=bucket, Key=during1_path+"corona_tweets_"+ str(i) + ".csv")
    df = pd.read_csv(io.BytesIO(obj['Body'].read()))
    all_df_during1.append(df)
    
# for i in range(654,743):
#     print(i)
#     obj = s3_client.get_object(Bucket=bucket, Key=during2_path+"corona_tweets_"+ str(i) + ".csv")
#     df = pd.read_csv(io.BytesIO(obj['Body'].read()))
#     all_df_during2.append(df)

# for i in range(988,1078):
#     print(i)
#     obj = s3_client.get_object(Bucket=bucket, Key=post_path+"corona_tweets_"+ str(i) + ".csv")
#     df = pd.read_csv(io.BytesIO(obj['Body'].read()))
#     all_df_post.append(df)

print("finish collecting response")
print(all_df_during1)

# %%
# import pandas as pd
# import boto3
# import io

# s3_file_key = 'unhydrated-data/during-covid-1/corona_tweets_258.csv'
# bucket = "is434-g1t5"

# s3 = boto3.client('s3')
# obj = s3.get_object(Bucket=bucket, Key=s3_file_key)

# initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()))

# initial_df

# %%
t = Twarc(consumer_key, consumer_secret, access_token, access_token_secret)
output = []

for tweet in t.hydrate(open('data/corona_tweets_377.csv')):
    print(tweet['full_text'])
    print(tweet['id'])
    print(tweet)
    #output[tweet['id']] = {'created_at': tweet['created_at'],'full_text' : tweet['full_text'], 'username' : tweet['user']['name'], 'user_id': tweet['user']['id'], 'user_location' : tweet['user']['location'],'followers_count' : tweet['user']['followers_count'], 'friends_count' : tweet['user']['friends_count'], 'verfied': tweet['user']['verified']}
    output.append({'created_at': tweet['created_at'],'full_text' : tweet['full_text'], 'username' : tweet['user']['name'], 'user_id': tweet['user']['id']})

# try:
#     df = pd.read_csv('data/corona_tweets_377.csv')
#     for index, row in df.iterrows():
#         tweet_id = row['id']
#         for tweet in t.hydrate([tweet_id]):
#             output[tweet_id] = {'created_at': tweet['created_at'],'full_text' : tweet['full_text'], 'username' : tweet['user']['name'], 'user_id': tweet['user']['id']}
#             print(tweet['full_text'])
#             print(tweet['id'])
#             print(tweet)
# except Exception as e:
#     print(f"Error: {e}")

# %%
print(len(output))

# %%
output

# %%
#https://twarc-project.readthedocs.io/en/latest/twarc2_en_us/

# %%
# import json
# json_string = json.dumps(output)
# with open('json_data.json', 'w') as outfile:
#     outfile.write(json_string)

# %% [markdown]
# # Version 2

# %% [markdown]
# # During 1

# %%
#Extact top 200 twitter users

import snscrape.modules.twitter as sntwitter
import pandas as pd
from collections import Counter

from datetime import datetime

print(datetime.now())
# Creating set to keep track of unique tweet IDs
tweet_ids = set()

# Creating list to append tweet data to
tweets_list = []

# search terms
search_terms =['covid', 'coronavirus','vaccine','vax', 'Pfizer', 'BioNTech', 'Sinopharm', 'Sinovac', 'Moderna','Oxford/AstraZeneca','AstraZeneca','Covaxin', 'Sputnik']

search_terms_str = '(covid OR coronavirus OR vaccine OR vax OR Pfizer OR BioNTech OR Sinopharm OR Sinovac OR Moderna OR Oxford/AstraZeneca OR AstraZeneca OR Covaxin OR Sputnik)'
time_period = 'since:2020-12-01 until:2021-02-28'

# Set the number of tweets to scrape per search term
tweet_limit = 10000

count = 0
query = f'{search_terms_str} {time_period} lang:en'
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    # Check if tweet ID already exists in set
    count +=1
    print(tweet.id , " Count", count)
    if tweet.id in tweet_ids:
        continue
    else:
        tweet_ids.add(tweet.id)
        tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.url, tweet.user.location, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, tweet.replyCount , tweet.user.verified, tweet.hashtags])

    # Break out of loop when tweet_limit is reached
    if i >= tweet_limit:
        break

# Create a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'tweet_id', 'text', 'username', 'url', 'user_location','like_count','retweet_count','follower_count','reply_count','verified', 'hashtags'])

# Count the frequency of each username in the dataframe
username_counts = Counter(tweets_df['username'])

# Get the top 200 usernames based on frequency
top_usernames = [username for username, count in username_counts.most_common(200)]

# Print the top 200 usernames
print(top_usernames)
# Out:
# 2023-04-02 00:03:54.689144
# 1365813966790926343  Count 1
# 1365813965725564939  Count 2
# 1365813964756692993  Count 3
# 1365813964320501767  Count 4
# 1365813962173018113  Count 5
# 1365813959916285953  Count 6
# 1365813959333318656  Count 7
# 1365813958163111938  Count 8
# 1365813957227905030  Count 9
# 1365813955936083980  Count 10
# 1365813955399155716  Count 11
# 1365813953436160004  Count 12
# 1365813951880167425  Count 13
# 1365813950869352455  Count 14
# 1365813950349123584  Count 15
# 1365813950269464579  Count 16
# 1365813948642115585  Count 17
# 1365813943336398850  Count 18
# 1365813941419397121  Count 19
# 1365813940844965893  Count 20
# 1365813940828135427  Count 21
# 1365813940522020872  Count 22
# 1365813940165373953  Count 23
# 1365813938898825219  Count 24
# 1365813937728536581  Count 25
# 1365813936956862464  Count 26
# 1365813936918982657  Count 27
# 1365813936520499200  Count 28
# 1365813931814625282  Count 29
# 1365813931055407105  Count 30
# 1365813927465127940  Count 31
# 1365813925493678081  Count 32
# 1365813925082763266  Count 33
# 1365813922499076102  Count 34
# 1365813921660211207  Count 35
# 1365813921119150083  Count 36
# 1365813919567200259  Count 37
# 1365813919281995777  Count 38
# 1365813916148797441  Count 39
# 1365813914102099968  Count 40
# 1365813911208030213  Count 41
# 1365813910830473219  Count 42
# 1365813909844754435  Count 43
# 1365813909614190592  Count 44
# 1365813906980048896  Count 45
# 1365813905323343874  Count 46
# 1365813903536525312  Count 47
# 1365813902802620422  Count 48
# 1365813900458004487  Count 49
# 1365813898205609984  Count 50
# 1365813896033013761  Count 51
# 1365813890454614017  Count 52
# 1365813889817071617  Count 53
# 1365813886935576584  Count 54
# 1365813886847385602  Count 55
# 1365813885056475142  Count 56
# 1365813884985044994  Count 57
# 1365813881566883840  Count 58
# 1365813878572122123  Count 59
# 1365813874843385867  Count 60
# 1365813872326807553  Count 61
# 1365813871290761225  Count 62
# 1365813866123378688  Count 63
# 1365813864043003907  Count 64
# 1365813863623651329  Count 65
', '_vbrndn', 'namenzie', 'Beepr5', 'BNOFeed', 'ralphmorrison22', 'guardiannews', 'ArmstrongDrew', 'CNBC', 'JudexXavier', '_DrFrusci', 'tobbystweet', 'seashawol', 'zryanverse', 'qctimes', 'Mikejcl52', 'Justin_EAndrews', 'LatinoLdnOnt', 'inkylu_lu', 'Johnjenkins309', 'sondra_watkins', 'HesterMcQueen', 'ecobearwitness', 'allenfolsom3', 'PicoDeGallo14', 'norionakatsuji', 'BARDA', 'joedunford200', 'canisgallicus', 'WXII', 'BabeTruth2', 'hcextrak']

# %%
concat_stri = "from:"+str(top_usernames[0])

for i in range(1, len(top_usernames)):
    concat_stri += " OR from:"+top_usernames[i]
    
handles_stri = concat_stri
print(handles_stri)
print(datetime.now())
# Out:
# from:suhail1mirza OR from:nicktompan OR from:eeeer71 OR from:AhmadNorMaulana OR from:yasu_yasuno_sa OR from:TrendzNewsbd OR from:COVIDLive OR from:BenHssinAhmed2 OR from:AndyVermaut OR from:islandofcovid OR from:AquariusOnFire OR from:schisano85 OR from:GlobalPandemics OR from:VonPyotr OR from:SharonShepshan OR from:tazalot1981 OR from:latimes OR from:Ravie777 OR from:Mott_Mason OR from:newsfilterio OR from:Leedslad48 OR from:jlwoods0241 OR from:merapimanf OR from:BobinSea OR from:renztamayo OR from:pop_popculture OR from:durindale OR from:morning_news24h OR from:CTVNews OR from:unstoppable8672 OR from:boatratbown OR from:CGJr_carlos OR from:yahata11 OR from:LouWasHe OR from:andy68101744 OR from:mlauriat OR from:DefaultNu OR from:TraderMarcoCost OR from:VivekSubbiah OR from:Hibatu3 OR from:alicuff OR from:meer10001 OR from:jonathanrockoff OR from:JerrBoi OR from:Alan_Nishihara OR from:NuritBaytch OR from:NZStuff OR from:elvisjj OR from:WatchOurCity OR from:onelinernews123 OR from:CassieY4 OR from:SetTheoryVirus OR from:ZyiteGadgets OR from:bmangh OR from:roto_rua OR from:jayjames4 OR from:usatodaysun21 OR from:chuck85258 OR from:tjmakiboi OR from:Su15100307 OR from:Melodys_Musings OR from:jebender1 OR from:Reuters OR from:caa1000 OR from:DennisKendel OR from:TweeterSomebody OR from:Nesgirl914 OR from:Nan10 OR from:thedextazlab OR from:fox5dc OR from:EGirald OR from:MelanieMoore OR from:easyOntario OR from:JaxRaymond OR from:ErieNewsNow OR from:wbaltv11 OR from:RichinWriterss OR from:patricksgeaney OR from:Raphael_A_Bauer OR from:bornblonde0077 OR from:US_FDA OR from:corndnc1 OR from:SocialistVoice OR from:PAconsultants1 OR from:mcbc OR from:apokerplayer OR from:sapp_erlot OR from:alexselby1770 OR from:Okie_Resister OR from:DrAnthony OR from:HammerToe OR from:KodyKinsley OR from:DrEricDing OR from:1NewsNZ OR from:openletterbot OR from:helenbinchy OR from:AstorAaron OR from:Teelin OR from:leemorson3NUFC OR from:NedPagliarulo OR from:RobButl69654384 OR from:RavenHawk4 OR from:TheHinduScience OR from:thehill OR from:JulianneMcShane OR from:drpestuk OR from:sauceocho OR from:ReginaPhelps OR from:MBELTD OR from:AlyeskaDawn OR from:MarianneSkolek OR from:dubvNOW OR from:thinkpolca OR from:TALK1370 OR from:PulpNews OR from:509ShawnG OR from:chuckghunter OR from:ashishkjha OR from:MHGtweet OR from:BuckeyeFineArts OR from:HindustanTimes OR from:MikeTaddow OR from:jools6691 OR from:jt120651 OR from:LarcombePeter OR from:_avasharpe OR from:civility1799 OR from:TimesofNewsHUB OR from:bba7422847 OR from:unfard OR from:bottlecapkingnj OR from:feedpushr OR from:CHOMcgoo OR from:maryaalexand1 OR from:aldotjahjadi8 OR from:Djfury4412 OR from:StephenGutowski OR from:Care2much18 OR from:tlscadden1 OR from:PIX11News OR from:thomaskaine5 OR from:HealthNews_b OR from:itrixy OR from:meister_mitch OR from:koconews OR from:FriedrichHayek OR from:Chris_1791 OR from:debbiemac603 OR from:82669F OR from:darlenekrause35 OR from:globalissuesweb OR from:TinkerChip OR from:Jerusalem_Post OR from:EdCara4 OR from:Trendypedia2 OR from:AndrewMakeTweet OR from:DavidMPeirce1 OR from:wacotrib OR from:LNevilllle OR from:BulletinCurrent OR from:mailmenow OR from:CBSPhiladelphia OR from:q0mega OR from:skepticalraptor OR from:zyiteblog OR from:Laughatsaltyge1 OR from:AliezeMac OR from:Reuters_Health OR from:VIXC_News OR from:_vbrndn OR from:namenzie OR from:Beepr5 OR from:BNOFeed OR from:ralphmorrison22 OR from:guardiannews OR from:ArmstrongDrew OR from:CNBC OR from:JudexXavier OR from:_DrFrusci OR from:tobbystweet OR from:seashawol OR from:zryanverse OR from:qctimes OR from:Mikejcl52 OR from:Justin_EAndrews OR from:LatinoLdnOnt OR from:inkylu_lu OR from:Johnjenkins309 OR from:sondra_watkins OR from:HesterMcQueen OR from:ecobearwitness OR from:allenfolsom3 OR from:PicoDeGallo14 OR from:norionakatsuji OR from:BARDA OR from:joedunford200 OR from:canisgallicus OR from:WXII OR from:BabeTruth2 OR from:hcextrak
# 2023-04-02 01:28:08.812779

# %%
print(datetime.now())
# Creating set to keep track of unique tweet IDs
tweet_ids = set()

# Creating list to append tweet data to
tweets_list = []

# search terms
search_terms =['covid', 'coronavirus','vaccine','vax', 'Pfizer', 'BioNTech', 'Sinopharm', 'Sinovac', 'Moderna','Oxford/AstraZeneca','AstraZeneca','Covaxin', 'Sputnik']

search_terms_str = 'covid OR coronavirus OR vaccine OR vax OR Pfizer OR BioNTech OR Sinopharm OR Sinovac OR Moderna OR Oxford/AstraZeneca OR AstraZeneca OR Covaxin OR Sputnik'
time_period = 'since:2020-12-01 until:2021-02-28'

# Set the number of tweets to scrape per search term
tweet_limit = 10000

count = 0
query = f'{search_terms_str} {time_period} {handles_stri} lang:en'
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    # Check if tweet ID already exists in set
    count +=1
    print(tweet.id , " Count", count)
    if tweet.id in tweet_ids:
        continue
    else:
        tweet_ids.add(tweet.id)
        tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.url, tweet.user.location, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, tweet.replyCount , tweet.user.verified, tweet.hashtags])

    # Break out of loop when tweet_limit is reached
    if i >= tweet_limit:
        break

# Create a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'tweet_id', 'text', 'username', 'url', 'user_location','like_count','retweet_count','follower_count','reply_count','verified', 'hashtags'])

handles_stri = str(top_usernames[0])

for i in range(1, len(top_usernames)):
    concat_stri += " OR from:"+top_usernames[i]
    
print(handles_stri)
# Out:
# 2023-04-02 01:28:09.609573
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=covid+OR+coronavirus+OR+vaccine+OR+vax+OR+Pfizer+OR+BioNTech+OR+Sinopharm+OR+Sinovac+OR+Moderna+OR+Oxford%2FAstraZeneca+OR+AstraZeneca+OR+Covaxin+OR+Sputnik+since%3A2020-12-01+until%3A2021-02-28+from%3Asuhail1mirza+OR+from%3Anicktompan+OR+from%3Aeeeer71+OR+from%3AAhmadNorMaulana+OR+from%3Ayasu_yasuno_sa+OR+from%3ATrendzNewsbd+OR+from%3ACOVIDLive+OR+from%3ABenHssinAhmed2+OR+from%3AAndyVermaut+OR+from%3Aislandofcovid+OR+from%3AAquariusOnFire+OR+from%3Aschisano85+OR+from%3AGlobalPandemics+OR+from%3AVonPyotr+OR+from%3ASharonShepshan+OR+from%3Atazalot1981+OR+from%3Alatimes+OR+from%3ARavie777+OR+from%3AMott_Mason+OR+from%3Anewsfilterio+OR+from%3ALeedslad48+OR+from%3Ajlwoods0241+OR+from%3Amerapimanf+OR+from%3ABobinSea+OR+from%3Arenztamayo+OR+from%3Apop_popculture+OR+from%3Adurindale+OR+from%3Amorning_news24h+OR+from%3ACTVNews+OR+from%3Aunstoppable8672+OR+from%3Aboatratbown+OR+from%3ACGJr_carlos+OR+from%3Ayahata11+OR+from%3ALouWasHe+OR+from%3Aandy68101744+OR+from%3Amlauriat+OR+from%3ADefaultNu+OR+from%3ATraderMarcoCost+OR+from%3AVivekSubbiah+OR+from%3AHibatu3+OR+from%3Aalicuff+OR+from%3Ameer10001+OR+from%3Ajonathanrockoff+OR+from%3AJerrBoi+OR+from%3AAlan_Nishihara+OR+from%3ANuritBaytch+OR+from%3ANZStuff+OR+from%3Aelvisjj+OR+from%3AWatchOurCity+OR+from%3Aonelinernews123+OR+from%3ACassieY4+OR+from%3ASetTheoryVirus+OR+from%3AZyiteGadgets+OR+from%3Abmangh+OR+from%3Aroto_rua+OR+from%3Ajayjames4+OR+from%3Ausatodaysun21+OR+from%3Achuck85258+OR+from%3Atjmakiboi+OR+from%3ASu15100307+OR+from%3AMelodys_Musings+OR+from%3Ajebender1+OR+from%3AReuters+OR+from%3Acaa1000+OR+from%3ADennisKendel+OR+from%3ATweeterSomebody+OR+from%3ANesgirl914+OR+from%3ANan10+OR+from%3Athedextazlab+OR+from%3Afox5dc+OR+from%3AEGirald+OR+from%3AMelanieMoore+OR+from%3AeasyOntario+OR+from%3AJaxRaymond+OR+from%3AErieNewsNow+OR+from%3Awbaltv11+OR+from%3ARichinWriterss+OR+from%3Apatricksgeaney+OR+from%3ARaphael_A_Bauer+OR+from%3Abornblonde0077+OR+from%3AUS_FDA+OR+from%3Acorndnc1+OR+from%3ASocialistVoice+OR+from%3APAconsultants1+OR+from%3Amcbc+OR+from%3Aapokerplayer+OR+from%3Asapp_erlot+OR+from%3Aalexselby1770+OR+from%3AOkie_Resister+OR+from%3ADrAnthony+OR+from%3AHammerToe+OR+from%3AKodyKinsley+OR+from%3ADrEricDing+OR+from%3A1NewsNZ+OR+from%3Aopenletterbot+OR+from%3Ahelenbinchy+OR+from%3AAstorAaron+OR+from%3ATeelin+OR+from%3Aleemorson3NUFC+OR+from%3ANedPagliarulo+OR+from%3ARobButl69654384+OR+from%3ARavenHawk4+OR+from%3ATheHinduScience+OR+from%3Athehill+OR+from%3AJulianneMcShane+OR+from%3Adrpestuk+OR+from%3Asauceocho+OR+from%3AReginaPhelps+OR+from%3AMBELTD+OR+from%3AAlyeskaDawn+OR+from%3AMarianneSkolek+OR+from%3AdubvNOW+OR+from%3Athinkpolca+OR+from%3ATALK1370+OR+from%3APulpNews+OR+from%3A509ShawnG+OR+from%3Achuckghunter+OR+from%3Aashishkjha+OR+from%3AMHGtweet+OR+from%3ABuckeyeFineArts+OR+from%3AHindustanTimes+OR+from%3AMikeTaddow+OR+from%3Ajools6691+OR+from%3Ajt120651+OR+from%3ALarcombePeter+OR+from%3A_avasharpe+OR+from%3Acivility1799+OR+from%3ATimesofNewsHUB+OR+from%3Abba7422847+OR+from%3Aunfard+OR+from%3Abottlecapkingnj+OR+from%3Afeedpushr+OR+from%3ACHOMcgoo+OR+from%3Amaryaalexand1+OR+from%3Aaldotjahjadi8+OR+from%3ADjfury4412+OR+from%3AStephenGutowski+OR+from%3ACare2much18 ...
# 4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=covid+OR+coronavirus+OR+vaccine+OR+vax+OR+Pfizer+OR+BioNTech+OR+Sinopharm+OR+Sinovac+OR+Moderna+OR+Oxford%2FAstraZeneca+OR+AstraZeneca+OR+Covaxin+OR+Sputnik+since%3A2020-12-01+until%3A2021-02-28+from%3Asuhail1mirza+OR+from%3Anicktompan+OR+from%3Aeeeer71+OR+from%3AAhmadNorMaulana+OR+from%3Ayasu_yasuno_sa+OR+from%3ATrendzNewsbd+OR+from%3ACOVIDLive+OR+from%3ABenHssinAhmed2+OR+from%3AAndyVermaut+OR+from%3Aislandofcovid+OR+from%3AAquariusOnFire+OR+from%3Aschisano85+OR+from%3AGlobalPandemics+OR+from%3AVonPyotr+OR+from%3ASharonShepshan+OR+from%3Atazalot1981+OR+from%3Alatimes+OR+from%3ARavie777+OR+from%3AMott_Mason+OR+from%3Anewsfilterio+OR+from%3ALeedslad48+OR+from%3Ajlwoods0241+OR+from%3Amerapimanf+OR+from%3ABobinSea+OR+from%3Arenztamayo+OR+from%3Apop_popculture+OR+from%3Adurindale+OR+from%3Amorning_news24h+OR+from%3ACTVNews+OR+from%3Aunstoppable8672+OR+from%3Aboatratbown+OR+from%3ACGJr_carlos+OR+from%3Ayahata11+OR+from%3ALouWasHe+OR+from%3Aandy68101744+OR+from%3Amlauriat+OR+from%3ADefaultNu+OR+from%3ATraderMarcoCost+OR+from%3AVivekSubbiah+OR+from%3AHibatu3+OR+from%3Aalicuff+OR+from%3Ameer10001+OR+from%3Ajonathanrockoff+OR+from%3AJerrBoi+OR+from%3AAlan_Nishihara+OR+from%3ANuritBaytch+OR+from%3ANZStuff+OR+from%3Aelvisjj+OR+from%3AWatchOurCity+OR+from%3Aonelinernews123+OR+from%3ACassieY4+OR+from%3ASetTheoryVirus+OR+from%3AZyiteGadgets+OR+from%3Abmangh+OR+from%3Aroto_rua+OR+from%3Ajayjames4+OR+from%3Ausatodaysun21+OR+from%3Achuck85258+OR+from%3Atjmakiboi+OR+from%3ASu15100307+OR+from%3AMelodys_Musings+OR+from%3Ajebender1+OR+from%3AReuters+OR+from%3Acaa1000+OR+from%3ADennisKendel+OR+from%3ATweeterSomebody+OR+from%3ANesgirl914+OR+from%3ANan10+OR+from%3Athedextazlab+OR+from%3Afox5dc+OR+from%3AEGirald+OR+from%3AMelanieMoore+OR+from%3AeasyOntario+OR+from%3AJaxRaymond+OR+from%3AErieNewsNow+OR+from%3Awbaltv11+OR+from%3ARichinWriterss+OR+from%3Apatricksgeaney+OR+from%3ARaphael_A_Bauer+OR+from%3Abornblonde0077+OR+from%3AUS_FDA+OR+from%3Acorndnc1+OR+from%3ASocialistVoice+OR+from%3APAconsultants1+OR+from%3Amcbc+OR+from%3Aapokerplayer+OR+from%3Asapp_erlot+OR+from%3Aalexselby1770+OR+from%3AOkie_Resister+OR+from%3ADrAnthony+OR+from%3AHammerToe+OR+from%3AKodyKinsley+OR+from%3ADrEricDing+OR+from%3A1NewsNZ+OR+from%3Aopenletterbot+OR+from%3Ahelenbinchy+OR+from%3AAstorAaron+OR+from%3ATeelin+OR+from%3Aleemorson3NUFC+OR+from%3ANedPagliarulo+OR+from%3ARobButl69654384+OR+from%3ARavenHawk4+OR+from%3ATheHinduScience+OR+from%3Athehill+OR+from%3AJulianneMcShane+OR+from%3Adrpestuk+OR+from%3Asauceocho+OR+from%3AReginaPhelps+OR+from%3AMBELTD+OR+from%3AAlyeskaDawn+OR+from%3AMarianneSkolek+OR+from%3AdubvNOW+OR+from%3Athinkpolca+OR+from%3ATALK1370+OR+from%3APulpNews+OR+from%3A509ShawnG+OR+from%3Achuckghunter+OR+from%3Aashishkjha+OR+from%3AMHGtweet+OR+from%3ABuckeyeFineArts+OR+from%3AHindustanTimes+OR+from%3AMikeTaddow+OR+from%3Ajools6691+OR+from%3Ajt120651+OR+from%3ALarcombePeter+OR+from%3A_avasharpe+OR+from%3Acivility1799+OR+from%3ATimesofNewsHUB+OR+from%3Abba7422847+OR+from%3Aunfard+OR+from%3Abottlecapkingnj+OR+from%3Afeedpushr+OR+from%3ACHOMcgoo+OR+from%3Amaryaalexand1+OR+from%3Aaldotjahjadi8+OR+from%3ADjfury4412+OR+from%3AStephenGutowski+OR+from%3ACare2much18+OR ...
# Errors: content type is not JSON, content type is not JSON, content type is not JSON, content type is not JSON
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25900\4089916167.py in <module>
#      17 count = 0
#      18 query = f'{search_terms_str} {time_period} {handles_stri} lang:en'
# ---> 19 for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
#      20     # Check if tweet ID already exists in set
#      21     count +=1
#
# ~\AppData\Roaming\Python\Python39\site-packages\snscrape\modules\twitter.py in get_items(self)
#    1659                 del params['cursor']
#    1660
# -> 1661                 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', _TwitterAPIType.V2, params, paginationParams, cursor = self._cursor):
#    1662                         yield from self._v2_timeline_instructions_to_tweets_or_users(obj)
#    1663
#
# ~\AppData\Roaming\Python\Python39\site-packages\snscrape\modules\twitter.py in _iter_api_data(self, endpoint, apiType, params, paginationParams, cursor, direction)
#     759                 while True:
#     760                         _logger.info(f'Retrieving scroll page {cursor}')
# --> 761                         obj = self._get_api_data(endpoint, apiType, reqParams)
#     762                         yield obj
#     763
#
# ~\AppData\Roaming\Python\Python39\site-packages\snscrape\modules\twitter.py in _get_api_data(self, endpoint, apiType, params)
#     725                 if apiType is _TwitterAPIType.GRAPHQL:
#     726                         params = urllib.parse.urlencode({k: json.dumps(v, separators = (',', ':')) for k, v in params.items()}, quote_via = urllib.parse.quote)
# --> 727                 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = self._check_api_response)
#     728                 try:
#     729                         obj = r.json()
#
# ~\AppData\Roaming\Python\Python39\site-packages\snscrape\base.py in _get(self, *args, **kwargs)
#     249
#     250         def _get(self, *args, **kwargs):
# --> 251                 return self._request('GET', *args, **kwargs)
#     252
#     253         def _post(self, *args, **kwargs):
#
# ~\AppData\Roaming\Python\Python39\site-packages\snscrape\base.py in _request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects, proxies)
#     245                         _logger.fatal(msg)
#     246                         _logger.fatal(f'Errors: {", ".join(errors)}')
# --> 247                         raise ScraperException(msg)
#     248                 raise RuntimeError('Reached unreachable code')
#     249
#
# ScraperException: 4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=covid+OR+coronavirus+OR+vaccine+OR+vax+OR+Pfizer+OR+BioNTech+OR+Sinopharm+OR+Sinovac+OR+Moderna+OR+Oxford%2FAstraZeneca+OR+AstraZeneca+OR+Covaxin+OR+Sputnik+since%3A2020-12-01+until%3A2021-02-28+from%3Asuhail1mirza+OR+from%3Anicktompan+OR+from%3Aeeeer71+OR+from%3AAhmadNorMaulana+OR+from%3Ayasu_yasuno_sa+OR+from%3ATrendzNewsbd+OR+from%3ACOVIDLive+OR+from%3ABenHssinAhmed2+OR+from%3AAndyVermaut+OR+from%3Aislandofcovid+OR+from%3AAquariusOnFire+OR+from%3Aschisano85+OR+from%3AGlobalPandemics+OR+from%3AVonPyotr+OR+from%3ASharonShepshan+OR+from%3Atazalot1981+OR+from%3Alatimes+OR+from%3ARavie777+OR+from%3AMott_Mason+OR+from%3Anewsfilterio+OR+from%3ALeedslad48+OR+from%3Ajlwoods0241+OR+from%3Amerapimanf+OR+from%3ABobinSea+OR+from%3Arenztamayo+OR+from%3Apop_popculture+OR+from%3Adurindale+OR+from%3Amorning_news24h+OR+from%3ACTVNews+OR+from%3Aunstoppable8672+OR+from%3Aboatratbown+OR+from%3ACGJr_carlos+OR+from%3Ayahata11+OR+from%3ALouWasHe+OR+from%3Aandy68101744+OR+from%3Amlauriat+OR+from%3ADefaultNu+OR+from%3ATraderMarcoCost+OR+from%3AVivekSubbiah+OR+from%3AHibatu3+OR+from%3Aalicuff+OR+from%3Ameer10001+OR+from%3Ajonathanrockoff+OR+from%3AJerrBoi+OR+from%3AAlan_Nishihara+OR+from%3ANuritBaytch+OR+from%3ANZStuff+OR+from%3Aelvisjj+OR+from%3AWatchOurCity+OR+from%3Aonelinernews123+OR+from%3ACassieY4+OR+from%3ASetTheoryVirus+OR+from%3AZyiteGadgets+OR+from%3Abmangh+OR+from%3Aroto_rua+OR+from%3Ajayjames4+OR+from%3Ausatodaysun21+OR+from%3Achuck85258+OR+from%3Atjmakiboi+OR+from%3ASu15100307+OR+from%3AMelodys_Musings+OR+from%3Ajebender1+OR+from%3AReuters+OR+from%3Acaa1000+OR+from%3ADennisKendel+OR+from%3ATweeterSomebody+OR+from%3ANesgirl914+OR+from%3ANan10+OR+from%3Athedextazlab+OR+from%3Afox5dc+OR+from%3AEGirald+OR+from%3AMelanieMoore+OR+from%3AeasyOntario+OR+from%3AJaxRaymond+OR+from%3AErieNewsNow+OR+from%3Awbaltv11+OR+from%3ARichinWriterss+OR+from%3Apatricksgeaney+OR+from%3ARaphael_A_Bauer+OR+from%3Abornblonde0077+OR+from%3AUS_FDA+OR+from%3Acorndnc1+OR+from%3ASocialistVoice+OR+from%3APAconsultants1+OR+from%3Amcbc+OR+from%3Aapokerplayer+OR+from%3Asapp_erlot+OR+from%3Aalexselby1770+OR+from%3AOkie_Resister+OR+from%3ADrAnthony+OR+from%3AHammerToe+OR+from%3AKodyKinsley+OR+from%3ADrEricDing+OR+from%3A1NewsNZ+OR+from%3Aopenletterbot+OR+from%3Ahelenbinchy+OR+from%3AAstorAaron+OR+from%3ATeelin+OR+from%3Aleemorson3NUFC+OR+from%3ANedPagliarulo+OR+from%3ARobButl69654384+OR+from%3ARavenHawk4+OR+from%3ATheHinduScience+OR+from%3Athehill+OR+from%3AJulianneMcShane+OR+from%3Adrpestuk+OR+from%3Asauceocho+OR+from%3AReginaPhelps+OR+from%3AMBELTD+OR+from%3AAlyeskaDawn+OR+from%3AMarianneSkolek+OR+from%3AdubvNOW+OR+from%3Athinkpolca+OR+from%3ATALK1370+OR+from%3APulpNews+OR+from%3A509ShawnG+OR+from%3Achuckghunter+OR+from%3Aashishkjha+OR+from%3AMHGtweet+OR+from%3ABuckeyeFineArts+OR+from%3AHindustanTimes+OR+from%3AMikeTaddow+OR+from%3Ajools6691+OR+from%3Ajt120651+OR+from%3ALarcombePeter+OR+from%3A_avasharpe+OR+from%3Acivility1799+OR+from%3ATimesofNewsHUB+OR+from%3Abba7422847+OR+from%3Aunfard+OR+from%3Abottlecapkingnj+OR+from%3Afeedpushr+OR+from%3ACHOMcgoo+OR+from%3Amaryaalexand1+OR+from%3Aaldotjahjadi8+OR+from%3ADjfury4412+OR+from%3AStephenGutowski+OR+fro ...

# %%
tweets_df
#ended
print(datetime.now())

# %%
tweets_df.to_csv('during1_covidTweets.csv', index=False)

# %% [markdown]
# # During2

# %%
#Extact top 200 twitter users

import snscrape.modules.twitter as sntwitter
import pandas as pd
from collections import Counter

from datetime import datetime

print(datetime.now())
# Creating set to keep track of unique tweet IDs
tweet_ids = set()

# Creating list to append tweet data to
tweets_list = []

# search terms
search_terms =['covid', 'coronavirus','vaccine','vax', 'Pfizer', 'BioNTech', 'Sinopharm', 'Sinovac', 'Moderna','Oxford/AstraZeneca','AstraZeneca','Covaxin', 'Sputnik']

search_terms_str = '(covid OR coronavirus OR vaccine OR vax OR Pfizer OR BioNTech OR Sinopharm OR Sinovac OR Moderna OR Oxford/AstraZeneca OR AstraZeneca OR Covaxin OR Sputnik)'
time_period = 'since:2022-01-01 until:2022-03-31'

# Set the number of tweets to scrape per search term
tweet_limit = 10000

count = 0
query = f'{search_terms_str} {time_period} lang:en'
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    # Check if tweet ID already exists in set
    count +=1
    print(tweet.id , " Count", count)
    if tweet.id in tweet_ids:
        continue
    else:
        tweet_ids.add(tweet.id)
        tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.url, tweet.user.location, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, tweet.replyCount , tweet.user.verified, tweet.hashtags])

    # Break out of loop when tweet_limit is reached
    if i >= tweet_limit:
        break

# Create a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'tweet_id', 'text', 'username', 'url', 'user_location','like_count','retweet_count','follower_count','reply_count','verified', 'hashtags'])

# Count the frequency of each username in the dataframe
username_counts = Counter(tweets_df['username'])

# Get the top 200 usernames based on frequency
top_usernames = [username for username, count in username_counts.most_common(200)]

# Print the top 200 usernames
print(top_usernames)

# %%
concat_stri = "from:"+str(top_usernames[0])

for i in range(1, len(top_usernames)):
    concat_stri += " OR from:"+top_usernames[i]
    
handles_stri = concat_stri
print(handles_stri)
print(datetime.now())
# Out:
# from:suhail1mirza OR from:nicktompan OR from:eeeer71 OR from:AhmadNorMaulana OR from:yasu_yasuno_sa OR from:TrendzNewsbd OR from:COVIDLive OR from:BenHssinAhmed2 OR from:AndyVermaut OR from:islandofcovid OR from:AquariusOnFire OR from:schisano85 OR from:GlobalPandemics OR from:VonPyotr OR from:SharonShepshan OR from:tazalot1981 OR from:latimes OR from:Ravie777 OR from:Mott_Mason OR from:newsfilterio OR from:Leedslad48 OR from:jlwoods0241 OR from:merapimanf OR from:BobinSea OR from:renztamayo OR from:pop_popculture OR from:durindale OR from:morning_news24h OR from:CTVNews OR from:unstoppable8672 OR from:boatratbown OR from:CGJr_carlos OR from:yahata11 OR from:LouWasHe OR from:andy68101744 OR from:mlauriat OR from:DefaultNu OR from:TraderMarcoCost OR from:VivekSubbiah OR from:Hibatu3 OR from:alicuff OR from:meer10001 OR from:jonathanrockoff OR from:JerrBoi OR from:Alan_Nishihara OR from:NuritBaytch OR from:NZStuff OR from:elvisjj OR from:WatchOurCity OR from:onelinernews123 OR from:CassieY4 OR from:SetTheoryVirus OR from:ZyiteGadgets OR from:bmangh OR from:roto_rua OR from:jayjames4 OR from:usatodaysun21 OR from:chuck85258 OR from:tjmakiboi OR from:Su15100307 OR from:Melodys_Musings OR from:jebender1 OR from:Reuters OR from:caa1000 OR from:DennisKendel OR from:TweeterSomebody OR from:Nesgirl914 OR from:Nan10 OR from:thedextazlab OR from:fox5dc OR from:EGirald OR from:MelanieMoore OR from:easyOntario OR from:JaxRaymond OR from:ErieNewsNow OR from:wbaltv11 OR from:RichinWriterss OR from:patricksgeaney OR from:Raphael_A_Bauer OR from:bornblonde0077 OR from:US_FDA OR from:corndnc1 OR from:SocialistVoice OR from:PAconsultants1 OR from:mcbc OR from:apokerplayer OR from:sapp_erlot OR from:alexselby1770 OR from:Okie_Resister OR from:DrAnthony OR from:HammerToe OR from:KodyKinsley OR from:DrEricDing OR from:1NewsNZ OR from:openletterbot OR from:helenbinchy OR from:AstorAaron OR from:Teelin OR from:leemorson3NUFC OR from:NedPagliarulo OR from:RobButl69654384 OR from:RavenHawk4 OR from:TheHinduScience OR from:thehill OR from:JulianneMcShane OR from:drpestuk OR from:sauceocho OR from:ReginaPhelps OR from:MBELTD OR from:AlyeskaDawn OR from:MarianneSkolek OR from:dubvNOW OR from:thinkpolca OR from:TALK1370 OR from:PulpNews OR from:509ShawnG OR from:chuckghunter OR from:ashishkjha OR from:MHGtweet OR from:BuckeyeFineArts OR from:HindustanTimes OR from:MikeTaddow OR from:jools6691 OR from:jt120651 OR from:LarcombePeter OR from:_avasharpe OR from:civility1799 OR from:TimesofNewsHUB OR from:bba7422847 OR from:unfard OR from:bottlecapkingnj OR from:feedpushr OR from:CHOMcgoo OR from:maryaalexand1 OR from:aldotjahjadi8 OR from:Djfury4412 OR from:StephenGutowski OR from:Care2much18 OR from:tlscadden1 OR from:PIX11News OR from:thomaskaine5 OR from:HealthNews_b OR from:itrixy OR from:meister_mitch OR from:koconews OR from:FriedrichHayek OR from:Chris_1791 OR from:debbiemac603 OR from:82669F OR from:darlenekrause35 OR from:globalissuesweb OR from:TinkerChip OR from:Jerusalem_Post OR from:EdCara4 OR from:Trendypedia2 OR from:AndrewMakeTweet OR from:DavidMPeirce1 OR from:wacotrib OR from:LNevilllle OR from:BulletinCurrent OR from:mailmenow OR from:CBSPhiladelphia OR from:q0mega OR from:skepticalraptor OR from:zyiteblog OR from:Laughatsaltyge1 OR from:AliezeMac OR from:Reuters_Health OR from:VIXC_News OR from:_vbrndn OR from:namenzie OR from:Beepr5 OR from:BNOFeed OR from:ralphmorrison22 OR from:guardiannews OR from:ArmstrongDrew OR from:CNBC OR from:JudexXavier OR from:_DrFrusci OR from:tobbystweet OR from:seashawol OR from:zryanverse OR from:qctimes OR from:Mikejcl52 OR from:Justin_EAndrews OR from:LatinoLdnOnt OR from:inkylu_lu OR from:Johnjenkins309 OR from:sondra_watkins OR from:HesterMcQueen OR from:ecobearwitness OR from:allenfolsom3 OR from:PicoDeGallo14 OR from:norionakatsuji OR from:BARDA OR from:joedunford200 OR from:canisgallicus OR from:WXII OR from:BabeTruth2 OR from:hcextrak
# 2023-04-02 01:27:43.185680

# %%
print(datetime.now())
# Creating set to keep track of unique tweet IDs
tweet_ids = set()

# Creating list to append tweet data to
tweets_list = []

# search terms
search_terms =['covid', 'coronavirus','vaccine','vax', 'Pfizer', 'BioNTech', 'Sinopharm', 'Sinovac', 'Moderna','Oxford/AstraZeneca','AstraZeneca','Covaxin', 'Sputnik']

search_terms_str = 'covid OR coronavirus OR vaccine OR vax OR Pfizer OR BioNTech OR Sinopharm OR Sinovac OR Moderna OR Oxford/AstraZeneca OR AstraZeneca OR Covaxin OR Sputnik'
time_period = 'since:2022-01-01 until:2022-03-31'

# Set the number of tweets to scrape per search term
tweet_limit = 10000

count = 0
query = f'{search_terms_str} {time_period} {handles_stri} lang:en'
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    # Check if tweet ID already exists in set
    count +=1
    print(tweet.id , " Count", count)
    if tweet.id in tweet_ids:
        continue
    else:
        tweet_ids.add(tweet.id)
        tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.url, tweet.user.location, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, tweet.replyCount , tweet.user.verified, tweet.hashtags])

    # Break out of loop when tweet_limit is reached
    if i >= tweet_limit:
        break

# Create a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'tweet_id', 'text', 'username', 'url', 'user_location','like_count','retweet_count','follower_count','reply_count','verified', 'hashtags'])

handles_stri = str(top_usernames[0])

for i in range(1, len(top_usernames)):
    concat_stri += " OR from:"+top_usernames[i]
    
print(handles_stri)

# %%
tweets_df
#ended
print(datetime.now())

# %%
tweets_df.to_csv('during2_covidTweets.csv', index=False)

# %% [markdown]
# # POST
#
# since:2020-01-01 until:2023-04-01

# %%
#Extact top 200 twitter users

import snscrape.modules.twitter as sntwitter
import pandas as pd
from collections import Counter

from datetime import datetime

print(datetime.now())
# Creating set to keep track of unique tweet IDs
tweet_ids = set()

# Creating list to append tweet data to
tweets_list = []

# search terms
search_terms =['covid', 'coronavirus','vaccine','vax', 'Pfizer', 'BioNTech', 'Sinopharm', 'Sinovac', 'Moderna','Oxford/AstraZeneca','AstraZeneca','Covaxin', 'Sputnik']

search_terms_str = '(covid OR coronavirus OR vaccine OR vax OR Pfizer OR BioNTech OR Sinopharm OR Sinovac OR Moderna OR Oxford/AstraZeneca OR AstraZeneca OR Covaxin OR Sputnik)'
time_period = 'since:2022-12-01 until:2023-02-28'

# Set the number of tweets to scrape per search term
tweet_limit = 10000

count = 0
query = f'{search_terms_str} {time_period} lang:en'
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    # Check if tweet ID already exists in set
    count +=1
    print(tweet.id , " Count", count)
    if tweet.id in tweet_ids:
        continue
    else:
        tweet_ids.add(tweet.id)
        tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.url, tweet.user.location, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, tweet.replyCount , tweet.user.verified, tweet.hashtags])

    # Break out of loop when tweet_limit is reached
    if i >= tweet_limit:
        break

# Create a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'tweet_id', 'text', 'username', 'url', 'user_location','like_count','retweet_count','follower_count','reply_count','verified', 'hashtags'])

# Count the frequency of each username in the dataframe
username_counts = Counter(tweets_df['username'])

# Get the top 200 usernames based on frequency
top_usernames = [username for username, count in username_counts.most_common(200)]

# Print the top 200 usernames
print(top_usernames)

# %%
concat_stri = str(top_usernames[0])

for i in range(1, len(top_usernames)):
    concat_stri += " OR "+top_usernames[i]
    
handles_stri = "("+concat_stri+")"
print(handles_stri)
print(datetime.now())

# %%
print(datetime.now())
# Creating set to keep track of unique tweet IDs
tweet_ids = set()

# Creating list to append tweet data to
tweets_list = []

# search terms
search_terms =['covid', 'coronavirus','vaccine','vax', 'Pfizer', 'BioNTech', 'Sinopharm', 'Sinovac', 'Moderna','Oxford/AstraZeneca','AstraZeneca','Covaxin', 'Sputnik']

search_terms_str = 'covid OR coronavirus OR vaccine OR vax OR Pfizer OR BioNTech OR Sinopharm OR Sinovac OR Moderna OR Oxford/AstraZeneca OR AstraZeneca OR Covaxin OR Sputnik'
time_period = 'since:2022-12-01 until:2023-02-28'

# Set the number of tweets to scrape per search term
tweet_limit = 10000

count = 0
query = f'{search_terms_str} {time_period} {handles_stri} lang:en'
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    # Check if tweet ID already exists in set
    count +=1
    print(tweet.id , " Count", count)
    if tweet.id in tweet_ids:
        continue
    else:
        tweet_ids.add(tweet.id)
        tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.url, tweet.user.location, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, tweet.replyCount , tweet.user.verified, tweet.hashtags])

    # Break out of loop when tweet_limit is reached
    if i >= tweet_limit:
        break

# Create a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['datetime', 'tweet_id', 'text', 'username', 'url', 'user_location','like_count','retweet_count','follower_count','reply_count','verified', 'hashtags'])

# %%
tweets_df
#ended
print(datetime.now())

# %%
tweets_df.to_csv('post_covidTweets.csv', index=False)
